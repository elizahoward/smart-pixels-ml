# %%
from Classes import PredictClusters
# Out:
# 2024-09-27 12:05:00.970692: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-09-27 12:05:00.973466: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-09-27 12:05:01.006302: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-27 12:05:01.006325: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-27 12:05:01.007355: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-27 12:05:01.012734: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-09-27 12:05:01.013121: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-27 12:05:01.658142: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/daq/venv/lib64/python3.9/site-packages/networkx/utils/backends.py:135: RuntimeWarning: networkx backend defined more than once: nx-loopback
#   backends.update(_get_backends("networkx.backends"))

# %%
data_path = "/home/elizahoward/cmspix28-mc-sim/MuC_Output/"
model = PredictClusters(data_directory_path = data_path, labels_directory_path=data_path, tag = '', include_y_local=True)
# Out:
# Directory /home/elizahoward/smart-pixels-ml/ouput/tfrecords_train_2f006e0f is removed...
# Processing Files...: 100%|██████████| 2/2 [00:01<00:00,  1.79it/s]
# Saving batches as TFRecords:   0%|          | 0/57 [00:00<?, ?it/s]2024-09-27 12:05:05.571664: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:274] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Saving batches as TFRecords: 100%|██████████| 57/57 [00:01<00:00, 38.54it/s]
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# --- Training generator 2.801865577697754 seconds ---
# Directory /home/elizahoward/smart-pixels-ml/ouput/tfrecords_validation_2f006e0f is removed...
# Processing Files...: 100%|██████████| 2/2 [00:00<00:00,  2.11it/s]
# Saving batches as TFRecords: 100%|██████████| 57/57 [00:01<00:00, 51.09it/s]
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# --- Validation generator 2.2716994285583496 seconds ---
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  X_input (InputLayer)        [(None, 13, 21, 2)]          0         []
#
#  q_separable_conv2d (QSepar  (None, 11, 19, 5)            33        ['X_input[0][0]']
#  ableConv2D)
#
#  q_activation (QActivation)  (None, 11, 19, 5)            0         ['q_separable_conv2d[0][0]']
#
#  q_conv2d (QConv2D)          (None, 11, 19, 5)            30        ['q_activation[0][0]']
#
#  q_activation_1 (QActivatio  (None, 11, 19, 5)            0         ['q_conv2d[0][0]']
#  n)
#
#  average_pooling2d (Average  (None, 3, 6, 5)              0         ['q_activation_1[0][0]']
#  Pooling2D)
#
#  q_activation_2 (QActivatio  (None, 3, 6, 5)              0         ['average_pooling2d[0][0]']
#  n)
#
#  flatten (Flatten)           (None, 90)                   0         ['q_activation_2[0][0]']
#
#  y_local_input (InputLayer)  [(None, 1)]                  0         []
#
#  concatenate (Concatenate)   (None, 91)                   0         ['flatten[0][0]',
#                                                                      'y_local_input[0][0]']
#
#  flatten_1 (Flatten)         (None, 91)                   0         ['concatenate[0][0]']
#
#  q_dense (QDense)            (None, 16)                   1472      ['flatten_1[0][0]']
#
#  q_activation_3 (QActivatio  (None, 16)                   0         ['q_dense[0][0]']
#  n)
#
#  q_dense_1 (QDense)          (None, 16)                   272       ['q_activation_3[0][0]']
#
#  q_activation_4 (QActivatio  (None, 16)                   0         ['q_dense_1[0][0]']
#  n)
#
#  q_dense_2 (QDense)          (None, 14)                   238       ['q_activation_4[0][0]']
#
# ==================================================================================================
# Total params: 2045 (7.99 KB)
# Trainable params: 2045 (7.99 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# --- Model create and compile 1.093785285949707 seconds ---
# Compiling model with learning rate: 0.001

# %%
#model.compileModel(learning_rate=0.001)
model.runTraining()
#model.loadWeights("/home/elizahoward/smart-pixels-ml/weights/weightsBIBsigPrediction.hdf5")
#model.loadWeights("/home/elizahoward/smart-pixels-ml/weights/weightsSigPrediction.hdf5")
# Out:
# Epoch 1/50
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[3], line 2
#       1 #model.compileModel(learning_rate=0.001)
# ----> 2 model.runTraining()
#       3 #model.loadWeights("/home/elizahoward/smart-pixels-ml/weights/weightsBIBsigPrediction.hdf5")
#       4 #model.loadWeights("/home/elizahoward/smart-pixels-ml/weights/weightsSigPrediction.hdf5")
#
# File ~/smart-pixels-ml/Classes.py:172, in PredictClusters.runTraining(self, epochs)
#     164 mcp = tf.keras.callbacks.ModelCheckpoint(
#     165     filepath=checkpoint_filepath,
#     166     save_weights_only=True,
#     167     monitor='val_loss',
#     168     save_best_only=True,
#     169 )
#     171 # train
# --> 172 self.history = self.model.fit(x=self.training_generator,
#     173                 validation_data=self.validation_generator,
#     174                 callbacks=[mcp],
#     175                 epochs=epochs,
#     176                 shuffle=False,
#     177                 verbose=1)
#     179 self.residuals = None
#
# File /home/daq/venv/lib64/python3.9/site-packages/tf_keras/src/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File /home/daq/venv/lib64/python3.9/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# InvalidArgumentError: Graph execution error:
#
# Detected at node model/concatenate/concat defined at (most recent call last):
#   File "/usr/lib64/python3.9/runpy.py", line 197, in _run_module_as_main
#
#   File "/usr/lib64/python3.9/runpy.py", line 87, in _run_code
#
#   File "/home/daq/venv/lib64/python3.9/site-packages/ipykernel_launcher.py", line 18, in <module>
#
#   File "/home/daq/venv/lib64/python3.9/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#
#   File "/home/daq/venv/lib64/python3.9/site-packages/ipykernel/kernelapp.py", line 739, in start
#
#   File "/home/daq/venv/lib64/python3.9/site-packages/tornado/platform/asyncio.py", line 205, in start
#
#   File "/usr/lib64/python3.9/asyncio/base_events.py", line 601, in run_forever
#
#   File "/usr/lib64/python3.9/asyncio/base_events.py", line 1905, in _run_once
#
#   File "/usr/lib64/python3.9/asyncio/events.py", line 80, in _run
#
#   File "/home/daq/venv/lib64/python3.9/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#
#   File "/home/daq/venv/lib64/python3.9/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#
#   File "/home/daq/venv/lib64/python3.9/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#
#   File "/home/daq/venv/lib64/python3.9/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#
#   File "/home/daq/venv/lib64/python3.9/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#
#   File "/home/daq/venv/lib64/python3.9/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#
#   File "/home/daq/venv/lib64/python3.9/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#
#   File "/home/daq/venv/lib64/python3.9/site-packages/IPython/core/interactiveshell.py", line 3048, in run_cell
#
#   File "/home/daq/venv/lib64/python3.9/site-packages/IPython/core/interactiveshell.py", line 3103, in _run_cell
#
#   File "/home/daq/venv/lib64/python3.9/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#
#   File "/home/daq/venv/lib64/python3.9/site-packages/IPython/core/interactiveshell.py", line 3308, in run_cell_async
#
#   File "/home/daq/venv/lib64/python3.9/site-packages/IPython/core/interactiveshell.py", line 3490, in run_ast_nodes
#
#   File "/home/daq/venv/lib64/python3.9/site-packages/IPython/core/interactiveshell.py", line 3550, in run_code
#
#   File "/tmp/ipykernel_70000/461667488.py", line 2, in <module>
#
#   File "/home/elizahoward/smart-pixels-ml/Classes.py", line 172, in runTraining
#
#   File "/home/daq/venv/lib64/python3.9/site-packages/tf_keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/home/daq/venv/lib64/python3.9/site-packages/tf_keras/src/engine/training.py", line 1804, in fit
#
#   File "/home/daq/venv/lib64/python3.9/site-packages/tf_keras/src/engine/training.py", line 1398, in train_function
#
#   File "/home/daq/venv/lib64/python3.9/site-packages/tf_keras/src/engine/training.py", line 1381, in step_function
#
#   File "/home/daq/venv/lib64/python3.9/site-packages/tf_keras/src/engine/training.py", line 1370, in run_step
#
#   File "/home/daq/venv/lib64/python3.9/site-packages/tf_keras/src/engine/training.py", line 1147, in train_step
#
#   File "/home/daq/venv/lib64/python3.9/site-packages/tf_keras/src/engine/training.py", line 553, in error_handler
#
#   File "/home/daq/venv/lib64/python3.9/site-packages/tf_keras/src/engine/training.py", line 558, in error_handler
#
#   File "/home/daq/venv/lib64/python3.9/site-packages/tf_keras/src/engine/training.py", line 588, in __call__
#
#   File "/home/daq/venv/lib64/python3.9/site-packages/tf_keras/src/engine/training.py", line 553, in error_handler
#
#   File "/home/daq/venv/lib64/python3.9/site-packages/tf_keras/src/engine/training.py", line 558, in error_handler
#
#   File "/home/daq/venv/lib64/python3.9/site-packages/tf_keras/src/engine/base_layer.py", line 1047, in __call__
#
#   File "/home/daq/venv/lib64/python3.9/site-packages/tf_keras/src/engine/base_layer.py", line 1136, in __call__
#
#   File "/tmp/__autograph_generated_filekiy_x56z.py", line 34, in error_handler
#
#   File "/home/daq/venv/lib64/python3.9/site-packages/tf_keras/src/engine/functional.py", line 514, in call
#
#   File "/home/daq/venv/lib64/python3.9/site-packages/tf_keras/src/engine/functional.py", line 661, in _run_internal_graph
#
#   File "/home/daq/venv/lib64/python3.9/site-packages/tf_keras/src/engine/functional.py", line 663, in _run_internal_graph
#
#   File "/home/daq/venv/lib64/python3.9/site-packages/tf_keras/src/engine/functional.py", line 663, in _run_internal_graph
#
#   File "/home/daq/venv/lib64/python3.9/site-packages/tf_keras/src/engine/functional.py", line 663, in _run_internal_graph
#
#   File "/home/daq/venv/lib64/python3.9/site-packages/tf_keras/src/engine/functional.py", line 671, in _run_internal_graph
#
#   File "/home/daq/venv/lib64/python3.9/site-packages/tf_keras/src/engine/training.py", line 553, in error_handler
#
#   File "/home/daq/venv/lib64/python3.9/site-packages/tf_keras/src/engine/training.py", line 558, in error_handler
#
#   File "/home/daq/venv/lib64/python3.9/site-packages/tf_keras/src/engine/base_layer.py", line 1047, in __call__
#
#   File "/home/daq/venv/lib64/python3.9/site-packages/tf_keras/src/engine/base_layer.py", line 1136, in __call__
#
#   File "/tmp/__autograph_generated_filekiy_x56z.py", line 34, in error_handler
#
#   File "/home/daq/venv/lib64/python3.9/site-packages/tf_keras/src/layers/merging/base_merge.py", line 127, in call
#
#   File "/home/daq/venv/lib64/python3.9/site-packages/tf_keras/src/layers/merging/base_merge.py", line 196, in call
#
#   File "/home/daq/venv/lib64/python3.9/site-packages/tf_keras/src/layers/merging/concatenate.py", line 134, in _merge_function
#
#   File "/home/daq/venv/lib64/python3.9/site-packages/tf_keras/src/backend.py", line 160, in error_handler
#
#   File "/home/daq/venv/lib64/python3.9/site-packages/tf_keras/src/backend.py", line 172, in error_handler
#
#   File "/home/daq/venv/lib64/python3.9/site-packages/tf_keras/src/backend.py", line 3582, in concatenate
#
# ConcatOp : Dimension 0 in both shapes must be equal: shape[0] = [500,90] vs. shape[1] = [2000,1]
# 	 [[{{node model/concatenate/concat}}]] [Op:__inference_train_function_6155]

# %%
model.checkResiduals()
# Out:
# 1/1 [==============================] - 1s 794ms/step
# 100%|██████████| 1/1 [00:00<00:00, 30.21it/s]
# Mean and standard deviation of residuals for x-midplane: (14.355926603317261,11.573142882748403)
# Mean and standard deviation of residuals for y-midplane: (7.78236493909359,5.240784509977043)
# Mean and standard deviation of residuals for cotAlpha: (1.3532858924344182,1.455345644522655)
# Mean and standard deviation of residuals for cotBeta: (1.282928193204105,1.772210139400743)

# %%
model.plotResiduals()

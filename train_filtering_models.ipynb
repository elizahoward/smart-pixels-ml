# %%
from Classes import *
data_path = "/home/elizahoward/MuonColliderSim/Simulation_Output/"
# Out:
# 2025-01-17 16:03:25.631188: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-01-17 16:03:25.631761: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-01-17 16:03:25.634967: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-01-17 16:03:25.643741: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %%
model=ClassificationModel(data_directory_path=data_path,
                          x_feature_description=['x_size', 'y_size', 'y_local', 'z_global'], stamp=5, cut_hit_time=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_3330982/2726915773.py in ?()
# ----> 1 model=ClassificationModel(data_directory_path=data_path,
#       2                           x_feature_description=['x_size', 'y_size', 'y_local', 'z_global'], stamp=5, cut_hit_time=True)
#
# ~/smart-pixels-ml/Classes.py in ?(self, data_directory_path, is_directory_recursive, file_type, data_format, batch_size, labels_list, units_list, normalization, muon_collider, file_fraction, to_standardize, input_shape, transpose, use_time_stamps, output_dir, learning_rate, tag, x_feature_description, filteringBIB, training_dir, model_number, stamp, cut_hit_time, hit_time_version)
#     393                  cut_hit_time: bool = False,
#     394                  hit_time_version: str = "adjusted_hit_time"
#     395                  ):
#     396
# ...

# %%
#model.compileModel(0.1)
model.runTraining(epochs=100)
# Out:
# 2025-01-17 14:09:09.338812: I tensorflow/core/kernels/data/tf_record_dataset_op.cc:370] TFRecordDataset `buffer_size` is unspecified, default to 262144
# Epoch 1/100
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 10s 51ms/step - binary_accuracy: 0.7140 - loss: 0.6769 - val_binary_accuracy: 0.3664 - val_loss: 0.7221 - learning_rate: 0.0010
# Epoch 2/100
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 9s 48ms/step - binary_accuracy: 0.3363 - loss: 0.7307 - val_binary_accuracy: 0.4499 - val_loss: 0.7207 - learning_rate: 0.0010
# Epoch 3/100
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 9s 48ms/step - binary_accuracy: 0.2763 - loss: 0.7521 - val_binary_accuracy: 0.4526 - val_loss: 0.7194 - learning_rate: 0.0010
# Epoch 4/100
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 9s 48ms/step - binary_accuracy: 0.2782 - loss: 0.7603 - val_binary_accuracy: 0.4526 - val_loss: 0.7160 - learning_rate: 0.0010
# Epoch 5/100
# ...

# %%
model.saveModel(model_number=4, overwrite=True)

# %%
model.checkAccuracy()
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step
# 100%|██████████| 45/45 [00:01<00:00, 24.96it/s]
# Signal Efficiency: 72.84%
# Background Rejection: 95.78%
#
# Overall Accuracy: 83.22%
# Fraction of Data that are Signal: 54.74%
#
# Total number of clusters: 13250

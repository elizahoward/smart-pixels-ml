# %%
from Classes import *
# Out:
# 2025-01-13 14:32:30.709928: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-01-13 14:32:30.712708: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-01-13 14:32:30.743436: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-13 14:32:30.743459: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# ...

# %%
model1 = ClassificationModel(training_dir="training_records1", model_number=1)
model2 = ClassificationModel(training_dir="training_records1", model_number=2)  
model3 = ClassificationModel(training_dir="training_records1", model_number=3)   
model4 = ClassificationModel(training_dir="training_records2", model_number=4)
# Out:
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# --- Training generator 0.12720298767089844 seconds ---
# --- Validation generator 0.1338787078857422 seconds ---
# 2025-01-13 14:32:33.356066: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:274] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Compiling model with learning rate: 0.001
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 model1 = ClassificationModel(training_dir="training_records1", model_number=1)
#       2 model2 = ClassificationModel(training_dir="training_records1", model_number=2)
#       3 model3 = ClassificationModel(training_dir="training_records1", model_number=3)
#
# ...

# %%
CompareModelROCCurves([model1, model2, model3, model4])
# Out:
# ...
# 45/45 [==============================] - 2s 40ms/step
# Optimal threshold for Model 1: 0.5852282047271729
# ...
# 45/45 [==============================] - 2s 41ms/step
# Optimal threshold for Model 2: 0.4943748116493225
# ...
# 45/45 [==============================] - 2s 40ms/step
# Optimal threshold for Model 3: 0.6297855377197266
# ...
# 45/45 [==============================] - 2s 42ms/step
# Optimal threshold for Model 4: 0.60044926404953

# %%
model4.checkAccuracy(threshold=0.6)
# Out:
# ...
# 100%|██████████| 45/45 [00:01<00:00, 25.61it/s]
# Signal Efficiency: 94.02%
# Background Rejection: 84.49%
#
# Overall Accuracy: 89.79%
# Fraction of Data that are Signal: 55.55%
#
# Total number of clusters: 13492

# %%
model4.plotROCcurve()
# Out:
# ...
# 45/45 [==============================] - 2s 42ms/step
# Optimal threshold: 0.60044926404953

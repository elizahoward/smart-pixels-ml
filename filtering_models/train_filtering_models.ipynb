# %%
import sys 
import os
parentdir = os.path.dirname(os.getcwd())
sys.path.insert(0, parentdir) 
from FilteringModel import *
# Out:
# 2025-05-15 17:14:38.523379: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-15 17:14:38.524076: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-05-15 17:14:38.527486: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-05-15 17:14:38.537169: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747347278.551766 3568624 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747347278.556109 3568624 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-15 17:14:38.571911: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /home/elizahoward/venv2/lib64/python3.9/site-packages/networkx/utils/backends.py:135: RuntimeWarning: networkx backend defined more than once: nx-loopback
#   backends.update(_get_backends("networkx.backends"))

# %%
model=FilteringModel(tf_records_dir=Path('./filtering_records2000').resolve(), x_feature_description=['x_size', 'y_size', 'y_local', 'z_global'], pairInputs=True,addDirectPath=True, classification_layer=[3,1], nSteps=150,learning_rate=0.01)
# Out:
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# 2025-05-15 17:14:56.229038: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ y_size (InputLayer) │ (None, 1)         │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y_local             │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ x_size (InputLayer) │ (None, 1)         │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ z_global            │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 2)         │          0 │ y_size[0][0],     │
# │ (Concatenate)       │                   │            │ y_local[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 2)         │          0 │ x_size[0][0],     │
# │ (Concatenate)       │                   │            │ z_global[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 3)         │          9 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 3)         │          9 │ concatenate_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 8)         │          0 │ dense[0][0],      │
# │ (Concatenate)       │                   │            │ y_size[0][0],     │
# │                     │                   │            │ dense_1[0][0],    │
# │                     │                   │            │ x_size[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 3)         │         27 │ concatenate_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 1)         │          4 │ dense_2[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 49 (196.00 B)
#  Trainable params: 49 (196.00 B)
#  Non-trainable params: 0 (0.00 B)
# Compiling model with learning rate: 0.01

# %%
#model.loadWeights('/home/elizahoward/smart-pixels-ml/filtering_models/parallel_training_90fab3/weights/Model 14_17000steps_clipnorm0.4.weights.h5')

# %%
#model.compileModel(0.0005)
model.runTraining(epochs=150,plotTraining=True)
# Out:
# 2025-05-15 17:14:56.907724: I tensorflow/core/kernels/data/tf_record_dataset_op.cc:370] TFRecordDataset `buffer_size` is unspecified, default to 262144
# Epoch 1/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - binary_accuracy: 0.3467 - loss: 0.7590 - val_binary_accuracy: 0.5552 - val_loss: 0.6876 - lr: 0.0100
# Epoch 2/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - binary_accuracy: 0.2907 - loss: 0.7416 - val_binary_accuracy: 0.5775 - val_loss: 0.6872 - lr: 0.0100
# Epoch 3/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - binary_accuracy: 0.4123 - loss: 0.7058 - val_binary_accuracy: 0.5741 - val_loss: 0.6865 - lr: 0.0100
# Epoch 4/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - binary_accuracy: 0.3585 - loss: 0.7014 - val_binary_accuracy: 0.5707 - val_loss: 0.6850 - lr: 0.0100
# Epoch 5/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - binary_accuracy: 0.2982 - loss: 0.7003 - val_binary_accuracy: 0.6049 - val_loss: 0.6821 - lr: 0.0100
# Epoch 6/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - binary_accuracy: 0.3888 - loss: 0.6995 - val_binary_accuracy: 0.5859 - val_loss: 0.6811 - lr: 0.0100
# Epoch 7/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - binary_accuracy: 0.4810 - loss: 0.6978 - val_binary_accuracy: 0.6638 - val_loss: 0.6746 - lr: 0.0100
# Epoch 8/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - binary_accuracy: 0.4638 - loss: 0.6954 - val_binary_accuracy: 0.6088 - val_loss: 0.6763 - lr: 0.0099
# Epoch 9/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - binary_accuracy: 0.5375 - loss: 0.6932 - val_binary_accuracy: 0.7129 - val_loss: 0.6650 - lr: 0.0099
# Epoch 10/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - binary_accuracy: 0.5024 - loss: 0.6879 - val_binary_accuracy: 0.6425 - val_loss: 0.6689 - lr: 0.0099
# Epoch 11/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - binary_accuracy: 0.5828 - loss: 0.6846 - val_binary_accuracy: 0.7202 - val_loss: 0.6549 - lr: 0.0099
# Epoch 12/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - binary_accuracy: 0.5446 - loss: 0.6749 - val_binary_accuracy: 0.6820 - val_loss: 0.6568 - lr: 0.0099
# Epoch 13/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - binary_accuracy: 0
# Epoch 145/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - binary_accuracy: 0.8426 - loss: 0.3885 - val_binary_accuracy: 0.8630 - val_loss: 0.3892 - lr: 5.3070e-05
# Epoch 146/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - binary_accuracy: 0.8426 - loss: 0.3885 - val_binary_accuracy: 0.8630 - val_loss: 0.3892 - lr: 4.2146e-05
# Epoch 147/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - binary_accuracy: 0.8426 - loss: 0.3884 - val_binary_accuracy: 0.8630 - val_loss: 0.3892 - lr: 3.3401e-05
# Epoch 148/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - binary_accuracy: 0.8426 - loss: 0.3884 - val_binary_accuracy: 0.8629 - val_loss: 0.3892 - lr: 2.6838e-05
# Epoch 149/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - binary_accuracy: 0.8426 - loss: 0.3884 - val_binary_accuracy: 0.8629 - val_loss: 0.3892 - lr: 2.2462e-05
# Epoch 150/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - binary_accuracy: 0.8426 - loss: 0.3884 - val_binary_accuracy: 0.8629 - val_loss: 0.3892 - lr: 2.0274e-05

# %%
model.plotROCcurve()
# Out:
# WARNING:tensorflow:5 out of the last 15 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7f09c42a6160> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 15 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7f09c42a6160> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step
# 100%|██████████| 7/7 [00:00<00:00, 19.49it/s]
# Optimal threshold: 0.5459979772567749

# %%
model.checkAccuracy(threshold=.5)
# Out:
# Overall Accuracy of Neural Network: 88.7%
# Fraction of Data that are Signal: 55.5%
#
# Neural Network results without cutting based on hit time:
#
#
# Signal Efficiency: 96.1%
# Background Rejection: 79.48%
#
#
# Neural Network results using hit time with 30ps gaussian:
#
#
# Signal Efficiency: 95.82%
# Background Rejection: 98.68%
#
#
# Cut results by themselves for 30 ps Gaussian:
#
#
# Signal Efficiency: 99.61%
# Background Rejection: 91.45%
#
#
# Total number of clusters: 13479

# %%
model.compareRejectedBIB(threshold=0.1)
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step
# 100%|██████████| 45/45 [00:02<00:00, 20.31it/s]

# %%
x1=np.mean(model.rejected_by_nn['x_size'])
x2=np.mean(model.rejected_by_time['x_size'])
x3=np.mean(model.rejected_by_both['x_size'])
x4=np.mean(model.not_rejected['x_size'])
x5=np.mean(model.sigInfo['x_size'])
print(f'Mean x-size for BIB rejected by neural network: {x1}\nMean x-size for BIB rejected by hit time cut: {x2}\nMean x-size for BIB rejected by both: {x3}\nMean x-size for BIB that were not rejected by either: {x4}\nMean x-size for signal: {x5}')
# Out:
# Mean x-size for BIB rejected by neural network: 3.1163206100463867
# Mean x-size for BIB rejected by hit time cut: 2.5234274864196777
# Mean x-size for BIB rejected by both: 2.6297967433929443
# Mean x-size for BIB that were not rejected by either: 2.895397424697876
# Mean x-size for signal: 2.688544273376465

# %%
x1=np.mean(model.rejected_by_nn['y_size'])
x2=np.mean(model.rejected_by_time['y_size'])
x3=np.mean(model.rejected_by_both['y_size'])
x4=np.mean(model.not_rejected['y_size'])
x5=np.mean(model.sigInfo['y_size'])
print(f'Mean y-size for BIB rejected by neural network: {x1}\nMean y-size for BIB rejected by hit time cut: {x2}\nMean y-size for BIB rejected by both: {x3}\nMean y-size for BIB that were not rejected by either: {x4}\nMean y-size for signal: {x5}')
# Out:
# Mean y-size for BIB rejected by neural network: 3.003937005996704
# Mean y-size for BIB rejected by hit time cut: 2.4494075775146484
# Mean y-size for BIB rejected by both: 2.450772762298584
# Mean y-size for BIB that were not rejected by either: 1.8577406406402588
# Mean y-size for signal: 1.6993716955184937

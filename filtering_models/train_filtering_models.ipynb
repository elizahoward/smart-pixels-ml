# %%
import sys 
import os
parentdir = os.path.dirname(os.getcwd())
sys.path.insert(0, parentdir) 
from FilteringModel import *
# Out:
# 2025-02-17 09:17:39.195211: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-02-17 09:17:39.195730: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-02-17 09:17:39.198668: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-02-17 09:17:39.207146: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %%
model=FilteringModel(tf_records_dir=Path('./filtering_records').resolve(), x_feature_description=['x_size', 'y_size', 'y_local', 'z_global'],model_number=4)
# Out:
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# 2025-02-17 10:19:43.772750: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Compiling model with learning rate: 0.001

# %%
#model.compileModel(0.0001)
model.runTraining(epochs=30)
# Out:
# 2025-02-17 10:19:59.149057: I tensorflow/core/kernels/data/tf_record_dataset_op.cc:370] TFRecordDataset `buffer_size` is unspecified, default to 262144
# Epoch 1/30
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 17s 80ms/step - binary_accuracy: 0.4744 - loss: 2.3879 - val_binary_accuracy: 0.5772 - val_loss: 0.9612 - learning_rate: 0.0010
# Epoch 2/30
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 16s 78ms/step - binary_accuracy: 0.6907 - loss: 0.7328 - val_binary_accuracy: 0.6346 - val_loss: 0.7498 - learning_rate: 0.0010
# Epoch 3/30
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 16s 79ms/step - binary_accuracy: 0.7785 - loss: 0.5375 - val_binary_accuracy: 0.6636 - val_loss: 0.6827 - learning_rate: 0.0010
# Epoch 4/30
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 16s 80ms/step - binary_accuracy: 0.8054 - loss: 0.4784 - val_binary_accuracy: 0.6817 - val_loss: 0.6340 - learning_rate: 0.0010
# Epoch 5/30
# ...

# %%
model.saveModel(model_number=4, overwrite=True)

# %%
model.checkAccuracy()
# Out:
# 2025-01-27 18:12:33.057093: I tensorflow/core/kernels/data/tf_record_dataset_op.cc:370] TFRecordDataset `buffer_size` is unspecified, default to 262144
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 8s 40ms/step
# 100%|██████████| 197/197 [00:07<00:00, 26.88it/s]
# Overall Accuracy of Neural Network: 91.31%
# Fraction of Data that are Signal: 52.42%
# Neural Network results without cutting based on hit time:
#
#
# Signal Efficiency: 96.17%
# Background Rejection: 85.96%
#
#
# Neural Network results using adjusted hit time:
#
#
# Signal Efficiency: 98.49%
# Background Rejection: 94.2%
#
#
# Neural Network results using adjusted hit time with 30ps gaussian:
#
#
# Signal Efficiency: 98.67%
# Background Rejection: 93.19%
#
#
# Neural Network results using adjusted hit time with 60ps gaussian:
#
#
# Signal Efficiency: 98.72%
# Background Rejection: 92.89%
#
#
#
# Total number of clusters: 59026
# Cut based results with original hit_time:
#
#
# Signal Efficiency: 63.64%
# Background Rejection: 56.93%
#
#
# ...

# %%
import sys
sys.path.append('.')  # Ensure OptimizedDataGenerator4.py is discoverable

import OptimizedDataGenerator4 as ODG
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from pathlib import Path
import matplotlib.pyplot as plt
from config import BASE_DIR, TRAIN_DIR, VALIDATION_DIR

base_dir      = BASE_DIR
train_dir     = TRAIN_DIR
validation_dir= VALIDATION_DIR

# ─── GPU memory growth ─────────────────────────────────────────────────────────
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)

# ─── Model definition ─────────────────────────────────────────────────────────
def CreateXYProfileModel():
    x_profile = tf.keras.Input(shape=(21, 1), name="x_profile")
    y_profile = tf.keras.Input(shape=(13, 1), name="y_profile")
    x_flat   = tf.keras.layers.Flatten(name="flatten_x")(x_profile)
    y_flat   = tf.keras.layers.Flatten(name="flatten_y")(y_profile)
    concat   = tf.keras.layers.Concatenate(name="concat_xy")([x_flat, y_flat])
    hidden1  = tf.keras.layers.Dense(64, activation="relu", name="hidden_128")(concat)
    hidden2  = tf.keras.layers.Dense(16, activation="relu", name="hidden_32")(hidden1)
    output   = tf.keras.layers.Dense(1, activation="sigmoid", name="output")(hidden2)
    return tf.keras.Model(inputs=[x_profile, y_profile], outputs=output)

# ─── Data generators factory ───────────────────────────────────────────────────

def make_gens():
    train_gen = ODG.OptimizedDataGenerator(
        load_records=True,
        tf_records_dir=str(TRAIN_DIR),
        x_feature_description=["x_profile", "y_profile"],
    )
    val_gen = ODG.OptimizedDataGenerator(
        load_records=True,
        tf_records_dir=str(VALIDATION_DIR),
        x_feature_description=["x_profile", "y_profile"],
    )
    return train_gen, val_gen

# ─── Single‐run trainer (returns full history) ────────────────────────────────
def train_and_evaluate(config):
    train_gen, val_gen = make_gens()
    steps = len(train_gen)
    epochs = 120

    model = CreateXYProfileModel()
    callbacks = [EarlyStopping(monitor="val_loss", patience=20, restore_best_weights=True)]

    kind = config["type"]
    if kind == "constant":
        optimizer = tf.keras.optimizers.Adam(learning_rate=config["lr"])
    elif kind == "cosine_decay":
        sched = tf.keras.optimizers.schedules.CosineDecay(
            initial_learning_rate=config["initial_lr"],
            decay_steps=steps * epochs,
            alpha=config.get("alpha", 0.0)
        )
        optimizer = tf.keras.optimizers.Adam(learning_rate=sched)
    elif kind == "cosine_restarts":
        sched = tf.keras.optimizers.schedules.CosineDecayRestarts(
            initial_learning_rate=config["initial_lr"],
            first_decay_steps=(steps * epochs) // config.get("restarts_divisor", 3),
            alpha=config.get("alpha", 0.0)
        )
        optimizer = tf.keras.optimizers.Adam(learning_rate=sched)
    elif kind == "exponential_decay":
        sched = tf.keras.optimizers.schedules.ExponentialDecay(
            initial_learning_rate=config["initial_lr"],
            decay_steps=(steps * epochs) // config.get("decay_divisor", 10),
            decay_rate=config.get("decay_rate", 0.96),
            staircase=config.get("staircase", True)
        )
        optimizer = tf.keras.optimizers.Adam(learning_rate=sched)
    elif kind == "polynomial_decay":
        sched = tf.keras.optimizers.schedules.PolynomialDecay(
            initial_learning_rate=config["initial_lr"],
            decay_steps=steps * epochs,
            end_learning_rate=config.get("end_lr", 1e-5),
            power=config.get("power", 1.0)
        )
        optimizer = tf.keras.optimizers.Adam(learning_rate=sched)
    elif kind == "inverse_time_decay":
        sched = tf.keras.optimizers.schedules.InverseTimeDecay(
            initial_learning_rate=config["initial_lr"],
            decay_steps=(steps * epochs) // config.get("decay_divisor", 10),
            decay_rate=config.get("decay_rate", 1.0),
            staircase=config.get("staircase", True)
        )
        optimizer = tf.keras.optimizers.Adam(learning_rate=sched)
    elif kind == "piecewise":
        sched = tf.keras.optimizers.schedules.PiecewiseConstantDecay(
            boundaries=config["boundaries"],
            values=config["values"]
        )
        optimizer = tf.keras.optimizers.Adam(learning_rate=sched)
    elif kind == "reduce_on_plateau":
        optimizer = tf.keras.optimizers.Adam(learning_rate=config["lr"])
        callbacks.append(ReduceLROnPlateau(
            monitor="val_loss",
            factor=config.get("factor", 0.5),
            patience=config.get("patience", 10),
            verbose=1
        ))
    else:
        raise ValueError(f"Unknown scheduler type {kind!r}")

    model.compile(optimizer=optimizer, loss="binary_crossentropy", metrics=["accuracy"])
    hist = model.fit(
        train_gen,
        validation_data=val_gen,
        epochs=epochs,
        steps_per_epoch=steps,
        callbacks=callbacks,
        shuffle=False,
        verbose=1
    ).history

    return hist

# ─── Configurations including all schedulers ──────────────────────────────────
configs = [
    {"name":"const_1e-3",     "type":"constant",         "lr":1e-3},
    {"name":"const_1e-4",     "type":"constant",         "lr":1e-4},
    {"name":"const_1e-2",     "type":"constant",         "lr":1e-2},
    {"name":"cosine_decay",   "type":"cosine_decay",     "initial_lr":1e-3, "alpha":0.0},
    {"name":"cosine_restarts","type":"cosine_restarts",  "initial_lr":1e-3, "restarts_divisor":3, "alpha":0.0},
    {"name":"exp_decay",      "type":"exponential_decay","initial_lr":1e-3, "decay_rate":0.96, "decay_divisor":10, "staircase":True},
    {"name":"poly_decay",     "type":"polynomial_decay", "initial_lr":1e-3, "end_lr":1e-5, "power":2.0},
    {"name":"inv_time_decay", "type":"inverse_time_decay","initial_lr":1e-3, "decay_rate":1.0, "decay_divisor":10, "staircase":True},
    {"name":"piecewise",      "type":"piecewise",        "boundaries":[3000,6000], "values":[1e-3,1e-4,1e-5]},
    {"name":"reduce_plateau", "type":"reduce_on_plateau","lr":1e-3, "factor":0.5, "patience":10},
]

# ─── Run sequentially and display progress ────────────────────────────────────
histories = {}
for cfg in configs:
    name = cfg["name"]
    print(f"\n=== Running scheduler: {name} ===")
    sys.stdout.flush()
    histories[name] = train_and_evaluate(cfg)
    print(f"Completed: {name}")
    sys.stdout.flush()

# ─── Plot all training & validation accuracy curves ───────────────────────────
plt.figure(figsize=(10, 6))
for name, h in histories.items():
    plt.plot(h['accuracy'], label=f'{name} train')
    plt.plot(h['val_accuracy'], '--', label=f'{name} val')
plt.title('Training & Validation Accuracy by LR Scheduler')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right', fontsize='small')
plt.grid(True)
plt.show()
# Out:
# === Running scheduler: const_1e-3 ===
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# Epoch 1/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 110ms/step - accuracy: 0.4312 - loss: 1.6461 - val_accuracy: 0.5964 - val_loss: 1.0623
# Epoch 2/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - accuracy: 0.3660 - loss: 1.2905 - val_accuracy: 0.6413 - val_loss: 0.7171
# Epoch 3/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.5312 - loss: 0.8708 - val_accuracy: 0.6569 - val_loss: 0.6978
# Epoch 4/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - accuracy: 0.5200 - loss: 0.8621 - val_accuracy: 0.6629 - val_loss: 0.6799
# Epoch 5/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.5263 - loss: 0.8339 - val_accuracy: 0.6669 - val_loss: 0.6645
# Epoch 6/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - accuracy: 0.5368 - loss: 0.8081 - val_accuracy: 0.6728 - val_loss: 0.6527
# Epoch 7/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.5492 - loss: 0.7867 - val_accuracy: 0.6738 - val_loss: 0.6458
# Epoch 8/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.5519 - loss: 0.7745 - val_accuracy: 0.6736 - val_loss: 0.6373
# Epoch 9/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.5565 - loss: 0.7595 - val_accuracy: 0.6732 - val_loss: 0.6301
# Epoch 10/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.5575 - loss: 0.7450 - val_accuracy: 0.6757 - val_loss: 0.6256
# Epoch 11/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.5574 - loss: 0.7369 - val_accuracy: 0.6772 - val_loss: 0.6219
# Epoch 12/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.5603 - loss: 0.7286 - val_accuracy: 0.6785 - val_loss: 0.6192
# Epoch 13/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.5612 - loss: 0.7234 - val_accuracy: 0.6790 - val_loss: 0.6156
# Epoch 14/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.5627 - loss: 0.7169 - val_accuracy: 0.6810 - val_loss: 0.6132
# Epoch 15/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.5644 - loss: 0.7120 - val_accuracy: 0.6805 - val_loss: 0.6111
# Epoch 16/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.5664 - loss: 0.7070 - val_accuracy: 0.6800 - val_loss: 0.6091
# Epoch 17/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - accuracy: 0.5680 - loss: 0.7027 - val_accuracy: 0.6803 - val_loss: 0.6070
# Epoch 18/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.
120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.6262 - loss: 0.6069 - val_accuracy: 0.6872 - val_loss: 0.5814
# Epoch 33/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.6269 - loss: 0.6057 - val_accuracy: 0.6885 - val_loss: 0.5811
# Epoch 34/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.6270 - loss: 0.6042 - val_accuracy: 0.6887 - val_loss: 0.5804
# Epoch 35/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.6277 - loss: 0.6027 - val_accuracy: 0.6886 - val_loss: 0.5801
# Epoch 36/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.6286 - loss: 0.6012 - val_accuracy: 0.6886 - val_loss: 0.5794
# Epoch 37/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.6285 - loss: 0.5997 - val_accuracy: 0.6885 - val_loss: 0.5791
# Epoch 38/120
# ...
# Epoch 17/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.6420 - loss: 0.6242 - val_accuracy: 0.6722 - val_loss: 0.6015 - learning_rate: 0.0010
# Epoch 18/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.6425 - loss: 0.6229 - val_accuracy: 0.6759 - val_loss: 0.6000 - learning_rate: 0.0010
# Epoch 19/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.6408 - loss: 0.6209 - val_accuracy: 0.6789 - val_loss: 0.5990 - learning_rate: 0.0010
# Epoch 20/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.6402 - loss: 0.6190 - val_accuracy: 0.6800 - val_loss: 0.5979 - learning_rate: 0.0010
# Epoch 21/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.6383 - loss: 0.6167 - val_accuracy: 0.6834 - val_loss: 0.5975 - learning_rate: 0.0010
# Epoch 22/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.6355 - loss: 0.6142 - val_accuracy: 0.6845 - val_loss: 0.5972 - learning_rate: 0.0010
# Epoch 23/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6357 - loss: 0.6109 - val_accuracy: 0.6842 - val_loss: 0.5947 - learning_rate: 0.0010
# Epoch 24/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6348 - loss: 0.6073 - val_accuracy: 0.6844 - val_loss: 0.5935 - learning_rate: 0.0010
# Epoch 25/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6254 - loss: 0.6065 - val_accuracy: 0.6844 - val_loss: 0.5926 - learning_rate: 0.0010
# Epoch 26/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6241 - loss: 0.6053 - val_accuracy: 0.6838 - val_loss: 0.5916 - learning_rate: 0.0010
# Epoch 27/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6202 - loss: 0.6038 - val_accuracy: 0.6845 - val_loss: 0.5906 - learning_rate: 0.0010
# Epoch 28/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6282 - loss: 0.6030 - val_accuracy: 0.6846 - val_loss: 0.5900 - learning_rate: 0.0010
# Epoch 29/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6341 - loss: 0.6017 - val_accuracy: 0.6854 - val_loss: 0.5890 - learning_rate: 0.0010
# Epoch 30/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6432 - loss: 0.6003 - val_accuracy: 0.6861 - val_loss: 0.5882 - learning_rate: 0.0010
# Epoch 31/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6418 - loss: 0.5987 - val_accuracy: 0.6849 - val_loss: 0.5873 - learning_rate: 0.0010
# Epoch 32/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6451 - loss: 0.5979 - val_accuracy: 0.6867 - val_loss: 0.5868 - learning_rate: 0.0010
# Epoch 33/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.6424 - loss: 0.5963 - val_accuracy: 0.6864 - val_loss: 0.5859 - learning_rate: 0.0010
# Epoch 34/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.6447 - loss: 0.5955 - val_accuracy: 0.6873 - val_loss: 0.5853 - learning_rate: 0.0010
# Epoch 35/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.6435 - loss: 0.5947 - val_accuracy: 0.6872 - val_loss: 0.5845 - learning_rate: 0.0010
# Epoch 36/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.6454 - loss: 0.5933 - val_accuracy: 0.6871 - val_loss: 0.5837 - learning_rate: 0.0010
# Epoch 37/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.6430 - loss: 0.5925 - val_accuracy: 0.6864 - val_loss: 0.5835 - learning_rate: 0.0010
# Epoch 38/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.6464 - loss: 0.5921 - val_accuracy: 0.6871 - val_loss: 0.5819 - learning_rate: 0.0010
# Epoch 39/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.6405 - loss: 0.5910 - val_accuracy: 0.6868 - val_loss: 0.5828 - learning_rate: 0.0010
# Epoch 40/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6455 - loss: 0.5922 - val_accuracy: 0.6886 - val_loss: 0.5808 - learning_rate: 0.0010
# Epoch 41/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6388 - loss: 0.5901 - val_accuracy: 0.6874 - val_loss: 0.5822 - learning_rate: 0.0010
# Epoch 42/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6440 - loss: 0.5915 - val_accuracy: 0.6886 - val_loss: 0.5799 - learning_rate: 0.0010
# Epoch 43/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.6397 - loss: 0.5889 - val_accuracy: 0.6877 - val_loss: 0.5815 - learning_rate: 0.0010
# Epoch 44/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.6445 - loss: 0.5896 - val_accuracy: 0.6880 - val_loss: 0.5792 - learning_rate: 0.0010
# Epoch 45/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.6399 - loss: 0.5867 - val_accuracy: 0.6866 - val_loss: 0.5801 - learning_rate: 0.0010
# Epoch 46/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6429 - loss: 0.5870 - val_accuracy: 0.6878 - val_loss: 0.5785 - learning_rate: 0.0010
# Epoch 47/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.6390 - loss: 0.5849 - val_accuracy: 0.6874 - val_loss: 0.5793 - learning_rate: 0.0010
# Epoch 48/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6396 - loss: 0.5851 - val_accuracy: 0.6876 - val_loss: 0.5776 - learning_rate: 0.0010
# Epoch 49/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.6370 - loss: 0.5835 - val_accuracy: 0.6874 - val_loss: 0.5784 - learning_rate: 0.0010
# Epoch 50/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.6388 - loss: 0.5839 - val_accuracy: 0.6883 - val_loss: 0.5770 - learning_rate: 0.0010
# Epoch 51/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.6376 - loss: 0.5824 - val_accuracy: 0.6872 - val_loss: 0.5777 - learning_rate: 0.0010
# Epoch 52/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.6380 - loss: 0.5831 - val_accuracy: 0.6883 - val_loss: 0.5764 - learning_rate: 0.0010
# Epoch 53/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.6384 - loss: 0.5813 - val_accuracy: 0.6878 - val_loss: 0.5770 - learning_rate: 0.0010
# Epoch 54/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.6390 - loss: 0.5825 - val_accuracy: 0.6885 - val_loss: 0.5760 - learning_rate: 0.0010
# Epoch 55/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6401 - loss: 0.5805 - val_accuracy: 0.6880 - val_loss: 0.5766 - learning_rate: 0.0010
# Epoch 56/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6361 - loss: 0.5803 - val_accuracy: 0.6883 - val_loss: 0.5759 - learning_rate: 0.0010
# Epoch 57/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6392 - loss: 0.5790 - val_accuracy: 0.6883 - val_loss: 0.5758 - learning_rate: 0.0010
# Epoch 58/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6395 - loss: 0.5782 - val_accuracy: 0.6893 - val_loss: 0.5750 - learning_rate: 0.0010
# Epoch 59/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6407 - loss: 0.5776 - val_accuracy: 0.6882 - val_loss: 0.5748 - learning_rate: 0.0010
# Epoch 60/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6394 - loss: 0.5768 - val_accuracy: 0.6898 - val_loss: 0.5741 - learning_rate: 0.0010
# Epoch 61/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6411 - loss: 0.5763 - val_accuracy: 0.6881 - val_loss: 0.5744 - learning_rate: 0.0010
# Epoch 62/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6379 - loss: 0.5761 - val_accuracy: 0.6897 - val_loss: 0.5738 - learning_rate: 0.0010
# Epoch 63/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6415 - loss: 0.5759 - val_accuracy: 0.6887 - val_loss: 0.5740 - learning_rate: 0.0010
# Epoch 64/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.6405 - loss: 0.5759 - val_accuracy: 0.6897 - val_loss: 0.5734 - learning_rate: 0.0010
# Epoch 65/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6420 - loss: 0.5749 - val_accuracy: 0.6888 - val_loss: 0.5736 - learning_rate: 0.0010
# Epoch 66/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6398 - loss: 0.5747 - val_accuracy: 0.6898 - val_loss: 0.5729 - learning_rate: 0.0010
# Epoch 67/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6419 - loss: 0.5742 - val_accuracy: 0.6888 - val_loss: 0.5731 - learning_rate: 0.0010
# Epoch 68/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6404 - loss: 0.5742 - val_accuracy: 0.6900 - val_loss: 0.5726 - learning_rate: 0.0010
# Epoch 69/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6419 - loss: 0.5738 - val_accuracy: 0.6894 - val_loss: 0.5728 - learning_rate: 0.0010
# Epoch 70/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - accuracy: 0.6411 - loss: 0.5734 - val_accuracy: 0.6902 - val_loss: 0.5723 - learning_rate: 0.0010
# Epoch 71/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.6420 - loss: 0.5732 - val_accuracy: 0.6897 - val_loss: 0.5725 - learning_rate: 0.0010
# Epoch 72/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6415 - loss: 0.5729 - val_accuracy: 0.6895 - val_loss: 0.5719 - learning_rate: 0.0010
# Epoch 73/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6419 - loss: 0.5722 - val_accuracy: 0.6896 - val_loss: 0.5721 - learning_rate: 0.0010
# Epoch 74/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6428 - loss: 0.5716 - val_accuracy: 0.6897 - val_loss: 0.5715 - learning_rate: 0.0010
# Epoch 75/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.6424 - loss: 0.5710 - val_accuracy: 0.6903 - val_loss: 0.5715 - learning_rate: 0.0010
# Epoch 76/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6433 - loss: 0.5706 - val_accuracy: 0.6907 - val_loss: 0.5709 - learning_rate: 0.0010
# Epoch 77/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.6441 - loss: 0.5698 - val_accuracy: 0.6906 - val_loss: 0.5709 - learning_rate: 0.0010
# Epoch 78/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.6433 - loss: 0.5695 - val_accuracy: 0.6900 - val_loss: 0.5708 - learning_rate: 0.0010
# Epoch 79/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6438 - loss: 0.5692 - val_accuracy: 0.6901 - val_loss: 0.5706 - learning_rate: 0.0010
# Epoch 80/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6435 - loss: 0.5691 - val_accuracy: 0.6910 - val_loss: 0.5705 - learning_rate: 0.0010
# Epoch 81/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6413 - loss: 0.5694 - val_accuracy: 0.6883 - val_loss: 0.5710 - learning_rate: 0.0010
# Epoch 82/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.6421 - loss: 0.5697 - val_accuracy: 0.6903 - val_loss: 0.5704 - learning_rate: 0.0010
# Epoch 83/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6444 - loss: 0.5686 - val_accuracy: 0.6894 - val_loss: 0.5701 - learning_rate: 0.0010
# Epoch 84/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6434 - loss: 0.5679 - val_accuracy: 0.6909 - val_loss: 0.5696 - learning_rate: 0.0010
# Epoch 85/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6410 - loss: 0.5679 - val_accuracy: 0.6897 - val_loss: 0.5702 - learning_rate: 0.0010
# Epoch 86/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6432 - loss: 0.5679 - val_accuracy: 0.6909 - val_loss: 0.5693 - learning_rate: 0.0010
# Epoch 87/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6435 - loss: 0.5672 - val_accuracy: 0.6887 - val_loss: 0.5700 - learning_rate: 0.0010
# Epoch 88/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6416 - loss: 0.5680 - val_accuracy: 0.6909 - val_loss: 0.5691 - learning_rate: 0.0010
# Epoch 89/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6434 - loss: 0.5665 - val_accuracy: 0.6894 - val_loss: 0.5695 - learning_rate: 0.0010
# Epoch 90/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.6431 - loss: 0.5670 - val_accuracy: 0.6909 - val_loss: 0.5688 - learning_rate: 0.0010
# Epoch 91/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6443 - loss: 0.5660 - val_accuracy: 0.6886 - val_loss: 0.5693 - learning_rate: 0.0010
# Epoch 92/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.6413 - loss: 0.5671 - val_accuracy: 0.6911 - val_loss: 0.5686 - learning_rate: 0.0010
# Epoch 93/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6406 - loss: 0.5655 - val_accuracy: 0.6888 - val_loss: 0.5693 - learning_rate: 0.0010
# Epoch 94/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6425 - loss: 0.5665 - val_accuracy: 0.6910 - val_loss: 0.5684 - learning_rate: 0.0010
# Epoch 95/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6378 - loss: 0.5657 - val_accuracy: 0.6878 - val_loss: 0.5692 - learning_rate: 0.0010
# Epoch 96/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6420 - loss: 0.5672 - val_accuracy: 0.6912 - val_loss: 0.5685 - learning_rate: 0.0010
# Epoch 97/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.6387 - loss: 0.5653 - val_accuracy: 0.6888 - val_loss: 0.5688 - learning_rate: 0.0010
# Epoch 98/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.6422 - loss: 0.5657 - val_accuracy: 0.6901 - val_loss: 0.5682 - learning_rate: 0.0010
# Epoch 99/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.6426 - loss: 0.5645 - val_accuracy: 0.6890 - val_loss: 0.5684 - learning_rate: 0.0010
# Epoch 100/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6429 - loss: 0.5648 - val_accuracy: 0.6912 - val_loss: 0.5677 - learning_rate: 0.0010
# Epoch 101/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6399 - loss: 0.5639 - val_accuracy: 0.6888 - val_loss: 0.5686 - learning_rate: 0.0010
# Epoch 102/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.6422 - loss: 0.5649 - val_accuracy: 0.6902 - val_loss: 0.5678 - learning_rate: 0.0010
# Epoch 103/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.6418 - loss: 0.5637 - val_accuracy: 0.6894 - val_loss: 0.5682 - learning_rate: 0.0010
# Epoch 104/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.6429 - loss: 0.5640 - val_accuracy: 0.6900 - val_loss: 0.5674 - learning_rate: 0.0010
# Epoch 105/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.6418 - loss: 0.5632 - val_accuracy: 0.6887 - val_loss: 0.5681 - learning_rate: 0.0010
# Epoch 106/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.6425 - loss: 0.5640 - val_accuracy: 0.6905 - val_loss: 0.5673 - learning_rate: 0.0010
# Epoch 107/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.6430 - loss: 0.5629 - val_accuracy: 0.6893 - val_loss: 0.5678 - learning_rate: 0.0010
# Epoch 108/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6434 - loss: 0.5633 - val_accuracy: 0.6900 - val_loss: 0.5672 - learning_rate: 0.0010
# Epoch 109/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.6437 - loss: 0.5624 - val_accuracy: 0.6895 - val_loss: 0.5676 - learning_rate: 0.0010
# Epoch 110/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6434 - loss: 0.5629 - val_accuracy: 0.6900 - val_loss: 0.5669 - learning_rate: 0.0010
# Epoch 111/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6428 - loss: 0.5639 - val_accuracy: 0.6889 - val_loss: 0.5678 - learning_rate: 0.0010
# Epoch 112/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6408 - loss: 0.5638 - val_accuracy: 0.6890 - val_loss: 0.5674 - learning_rate: 0.0010
# Epoch 113/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.6432 - loss: 0.5621 - val_accuracy: 0.6896 - val_loss: 0.5675 - learning_rate: 0.0010
# Epoch 114/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6436 - loss: 0.5626 - val_accuracy: 0.6896 - val_loss: 0.5669 - learning_rate: 0.0010
# Epoch 115/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6435 - loss: 0.5615 - val_accuracy: 0.6894 - val_loss: 0.5675 - learning_rate: 0.0010
# Epoch 116/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6439 - loss: 0.5623 - val_accuracy: 0.6896 - val_loss: 0.5668 - learning_rate: 0.0010
# Epoch 117/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6448 - loss: 0.5612 - val_accuracy: 0.6892 - val_loss: 0.5673 - learning_rate: 0.0010
# Epoch 118/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6434 - loss: 0.5618 - val_accuracy: 0.6897 - val_loss: 0.5667 - learning_rate: 0.0010
# Epoch 119/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.6440 - loss: 0.5607 - val_accuracy: 0.6890 - val_loss: 0.5669 - learning_rate: 0.0010
# Epoch 120/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.6438 - loss: 0.5612 - val_accuracy: 0.6897 - val_loss: 0.5665 - learning_rate: 0.0010
# Completed: reduce_plateau

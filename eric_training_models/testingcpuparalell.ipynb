# %%
import sys
import os
from concurrent.futures import ProcessPoolExecutor, as_completed
from pathlib import Path
import matplotlib.pyplot as plt
from config import BASE_DIR, TRAIN_DIR, VALIDATION_DIR

# 1) Update this path to where OptimizedDataGenerator4.py resides
sys.path.append('.')  
os.environ['CUDA_VISIBLE_DEVICES'] = ''  # Force CPU-only

import OptimizedDataGenerator4 as ODG
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# ─── Model definition ─────────────────────────────────────────────────────────
def CreateXYProfileModel():
    x = tf.keras.Input((21,1), name="x_profile")
    y = tf.keras.Input((13,1), name="y_profile")
    xf = tf.keras.layers.Flatten()(x)
    yf = tf.keras.layers.Flatten()(y)
    c  = tf.keras.layers.Concatenate()([xf, yf])
    h1 = tf.keras.layers.Dense(64, activation="relu")(c)
    h2 = tf.keras.layers.Dense(16, activation="relu")(h1)
    out= tf.keras.layers.Dense(1, activation="sigmoid")(h2)
    return tf.keras.Model([x, y], out)

# ─── Data generators factory ───────────────────────────────────────────────────
base_dir       = BASE_DIR
train_dir      = TRAIN_DIR
validation_dir = VALIDATION_DIR

def make_gens():
    train_gen = ODG.OptimizedDataGenerator(
        load_records=True,
        tf_records_dir=str(TRAIN_DIR),
        x_feature_description=["x_profile", "y_profile"],
    )
    val_gen = ODG.OptimizedDataGenerator(
        load_records=True,
        tf_records_dir=str(VALIDATION_DIR),
        x_feature_description=["x_profile", "y_profile"],
    )
    return train_gen, val_gen

# ─── Single‐run trainer (returns full history) ────────────────────────────────
def train_and_evaluate(config):
    # Enable CPU-only (already set globally)
    train_gen, val_gen = make_gens()
    steps, epochs = len(train_gen), 120

    model = CreateXYProfileModel()
    callbacks = [EarlyStopping(monitor="val_loss", patience=20, restore_best_weights=True)]

    kind = config["type"]
    if kind == "constant":
        optimizer = tf.keras.optimizers.Adam(learning_rate=config["lr"])
    elif kind == "cosine_decay":
        sched = tf.keras.optimizers.schedules.CosineDecay(
            initial_learning_rate=config["initial_lr"],
            decay_steps=steps * epochs,
            alpha=config.get("alpha", 0.0)
        )
        optimizer = tf.keras.optimizers.Adam(learning_rate=sched)
    elif kind == "cosine_restarts":
        sched = tf.keras.optimizers.schedules.CosineDecayRestarts(
            initial_learning_rate=config["initial_lr"],
            first_decay_steps=(steps * epochs) // config.get("restarts_divisor", 3),
            alpha=config.get("alpha", 0.0)
        )
        optimizer = tf.keras.optimizers.Adam(learning_rate=sched)
    elif kind == "exponential_decay":
        sched = tf.keras.optimizers.schedules.ExponentialDecay(
            initial_learning_rate=config["initial_lr"],
            decay_steps=(steps * epochs) // config.get("decay_divisor", 10),
            decay_rate=config.get("decay_rate", 0.96),
            staircase=config.get("staircase", True)
        )
        optimizer = tf.keras.optimizers.Adam(learning_rate=sched)
    elif kind == "polynomial_decay":
        sched = tf.keras.optimizers.schedules.PolynomialDecay(
            initial_learning_rate=config["initial_lr"],
            decay_steps=steps * epochs,
            end_learning_rate=config.get("end_lr", 1e-5),
            power=config.get("power", 1.0)
        )
        optimizer = tf.keras.optimizers.Adam(learning_rate=sched)
    elif kind == "inverse_time_decay":
        sched = tf.keras.optimizers.schedules.InverseTimeDecay(
            initial_learning_rate=config["initial_lr"],
            decay_steps=(steps * epochs) // config.get("decay_divisor", 10),
            decay_rate=config.get("decay_rate", 1.0),
            staircase=config.get("staircase", True)
        )
        optimizer = tf.keras.optimizers.Adam(learning_rate=sched)
    elif kind == "piecewise":
        sched = tf.keras.optimizers.schedules.PiecewiseConstantDecay(
            boundaries=config["boundaries"],
            values=config["values"]
        )
        optimizer = tf.keras.optimizers.Adam(learning_rate=sched)
    elif kind == "reduce_on_plateau":
        optimizer = tf.keras.optimizers.Adam(learning_rate=config["lr"])
        callbacks.append(ReduceLROnPlateau(
            monitor="val_loss",
            factor=config.get("factor", 0.5),
            patience=config.get("patience", 10),
            verbose=1
        ))
    else:
        raise ValueError(f"Unknown scheduler type {kind!r}")

    model.compile(optimizer=optimizer, loss="binary_crossentropy", metrics=["accuracy"])
    print(f"Starting '{config['name']}' on CPU")
    hist = model.fit(
        train_gen,
        validation_data=val_gen,
        epochs=epochs,
        steps_per_epoch=steps,
        callbacks=callbacks,
        shuffle=False,
        verbose=1
    ).history
    print(f"Completed '{config['name']}'")
    return config["name"], hist

# ─── All scheduler configurations ──────────────────────────────────────────────
configs = [
    {"name":"const_1e-3",     "type":"constant",          "lr":1e-3},
    {"name":"const_1e-4",     "type":"constant",          "lr":1e-4},
    {"name":"const_1e-2",     "type":"constant",          "lr":1e-2},
    {"name":"cosine_decay",   "type":"cosine_decay",      "initial_lr":1e-3, "alpha":0.0},
    {"name":"cosine_restarts","type":"cosine_restarts",   "initial_lr":1e-3, "restarts_divisor":3, "alpha":0.0},
    {"name":"exp_decay",      "type":"exponential_decay", "initial_lr":1e-3, "decay_rate":0.96, "decay_divisor":10, "staircase":True},
    {"name":"poly_decay",     "type":"polynomial_decay",  "initial_lr":1e-3, "end_lr":1e-5, "power":2.0},
    {"name":"inv_time_decay", "type":"inverse_time_decay","initial_lr":1e-3, "decay_rate":1.0, "decay_divisor":10, "staircase":True},
    {"name":"piecewise",      "type":"piecewise",         "boundaries":[3000,6000], "values":[1e-3,1e-4,1e-5]},
    {"name":"reduce_plateau", "type":"reduce_on_plateau", "lr":1e-3, "factor":0.5, "patience":10},
]

# ─── Run all in parallel on CPU ────────────────────────────────────────────────
histories = {}
with ProcessPoolExecutor(max_workers=len(configs)) as executor:
    futures = {executor.submit(train_and_evaluate, cfg): cfg["name"] for cfg in configs}
    for fut in as_completed(futures):
        name, hist = fut.result()
        histories[name] = hist

# ─── Plot separate graph for each scheduler ───────────────────────────────────
for name, h in histories.items():
    epochs = len(h['accuracy'])
    plt.figure(figsize=(8, 4))
    plt.plot(range(1, epochs+1), h['accuracy'], label='Train')
    plt.plot(range(1, epochs+1), h['val_accuracy'], '--', label='Validation')
    final_train = h['accuracy'][-1]
    final_val = h['val_accuracy'][-1]
    plt.title(f"{name}\nFinal Train={final_train:.4f}, Val={final_val:.4f}")
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend(loc='lower right')
    plt.grid(True)
    plt.show()
# Out:
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# Starting 'cosine_restarts' on CPU
# Starting 'const_1e-4' on CPU
# Starting 'exp_decay' on CPUStarting 'cosine_decay' on CPU
#
# Starting 'poly_decay' on CPU
# Starting 'reduce_plateau' on CPU
# Starting 'const_1e-2' on CPU
# Starting 'piecewise' on CPU
# Starting 'inv_time_decay' on CPU
# Starting 'const_1e-3' on CPU
# 2025-06-17 00:25:32.980213: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2025-06-17 00:25:32.980252: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:167] env: CUDA_VISIBLE_DEVICES=""
# 2025-06-17 00:25:32.980261: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:170] CUDA_VISIBLE_DEVICES is set to an empty string - this hides all GPUs from CUDA
# 2025-06-17 00:25:32.980272: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:178] verbose logging is disabled. Rerun with verbose logging (usually --v=1 or --vmodule=cuda_diagnostics=1) to get more diagnostic output from this module
# 2025-06-17 00:25:32.980276: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:183] retrieving CUDA diagnostic information for host: kdplab01
# 2025-06-17 00:25:32.980279: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:190] hostname: kdplab01
# 2025-06-17 00:25:32.980424: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:197] libcuda reported version is: 570.153.2
# 2025-06-17 00:25:32.980452: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:201] kernel reported version is: 570.153.2
# 2025-06-17 00:25:32.980455: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:291] kernel version seems to match DSO: 570.153.2
# 2025-06-17 00:25:32.982616: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2025-06-17 00:25:32.982651: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:167] env: CUDA_VISIBLE_DEVICES=""
# 2025-06-17 00:25:32.982660: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:170] CUDA_VISIBLE_DEVICES is set to an empty string - this hides all GPUs from CUDA
# 2025-06-17 00:25:32.982668: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:178] verbose logging is disabled. Rerun with verbose logging (usually --v=1 or --vmodule=cuda_diagnostics=1) to get more diagnostic output from this module
# 2025-06-17 00:25:32.982673: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:183] retrieving CUDA diagnostic information for host: kdplab01
# 2025-06-17 00:25:32.982675: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:190] hostname: kdplab01
# 2025-06-17 00:25:32.982876: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:197] libcuda reported version is: 570.153.2
# 2025-06-17 00:25:32.982907: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:201] kernel reported version is: 570.153.2
# 2025-06-17 00:25:32.982910: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:291] kernel version seems to match DSO: 570.153.2
# 2025-06-17 00:25:32.987321: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2025-06-17 00:25:32.987365: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:167] env: CUDA_VISIBLE_DEVICES=""
# 2025-06-17 00:25:32.987376: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:170] CUDA_VISIBLE_DEVICES is set to an empty string - this hides all GPUs from CUDA
# 2025-06-17 00:25:32.987388: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:178] verbose logging is disabled. Rerun with verbose logging (usually --v=1 or --vmodule=cuda_diagnostics=1) to get more diagnostic output from this module
# 2025-06-17 00:25:32.987394: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:183] retrieving CUDA diagnostic information for host: kdplab01
# 2025-06-17 00:25:32.987397: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:190] hostname: kdplab01
# 2025-06-17 00:25:32.987743: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:197] libcuda reported version is: 570.153.2
# 2025-06-17 00:25:32.987781: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:201] kernel reported version is: 570.153.2
# 2025-06-17 00:25:32.987785: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:291] kernel version seems to match DSO: 570.153.2
# 2025-06-17 00:25:33.002755: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2025-06-17 00:25:33.002798: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:167] env: CUDA_VISIBLE_DEVICES=""
# 2025-06-17 00:25:33.002809: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:170] CUDA_VISIBLE_DEVICES is set to an empty string - this hides all GPUs from CUDA
# 2025-06-17 00:25:33.002823: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:178] verbose logging is disabled. Rerun with verbose logging (usually --v=1 or --vmodule=cuda_diagnostics=1) to get more diagnostic output from this module
# 2025-06-17 00:25:33.002831: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:183] retrieving CUDA diagnostic information for host: kdplab01
# 2025-06-17 00:25:33.002834: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:190] hostname: kdplab01
# 2025-06-17 00:25:33.003179: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:197] libcuda reported version is: 570.153.2
# 2025-06-17 00:25:33.003205: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:201] kernel reported version is: 570.153.2
# 2025-06-17 00:25:33.003208: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:291] kernel version seems to match DSO: 570.153.2
# 2025-06-17 00:25:33.012044: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2025-06-17 00:25:33.012080: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:167] env: CUDA_VISIBLE_DEVICES=""
# 2025-06-17 00:25:33.012088: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:170] CUDA_VISIBLE_DEVICES is set to an empty string - this hides all GPUs from CUDA
# 2025-06-17 00:25:33.012095: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:178] verbose logging is disabled. Rerun with verbose logging (usually --v=1 or --vmodule=cuda_diagnostics=1) to get more diagnostic output from this module
# 2025-06-17 00:25:33.012100: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:183] retrieving CUDA diagnostic information for host: kdplab01
# 2025-06-17 00:25:33.012102: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:190] hostname: kdplab01
# 2025-06-17 00:25:33.012287: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:197] libcuda reported version is: 570.153.2
# 2025-06-17 00:25:33.012313: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:201] kernel reported version is: 570.153.2
# 2025-06-17 00:25:33.012316: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:291] kernel version seems to match DSO: 570.153.2
# 2025-06-17 00:25:33.013573: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2025-06-17 00:25:33.013634: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:167] env: CUDA_VISIBLE_DEVICES=""
# 2025-06-17 00:25:33.013649: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:170] CUDA_VISIBLE_DEVICES is set to an empty string - this hides all GPUs from CUDA
# 2025-06-17 00:25:33.013661: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:178] verbose logging is disabled. Rerun with verbose logging (usually --v=1 or --vmodule=cuda_diagnostics=1) to get more diagnostic output from this module
# 2025-06-17 00:25:33.013669: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:183] retrieving CUDA diagnostic information for host: kdplab01
# 2025-06-17 00:25:33.013674: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:190] hostname: kdplab01
# 2025-06-17 00:25:33.013783: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2025-06-17 00:25:33.013822: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:167] env: CUDA_VISIBLE_DEVICES=""
# 2025-06-17 00:25:33.013832: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:170] CUDA_VISIBLE_DEVICES is set to an empty string - this hides all GPUs from CUDA
# 2025-06-17 00:25:33.013840: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:178] verbose logging is disabled. Rerun with verbose logging (usually --v=1 or --vmodule=cuda_diagnostics=1) to get more diagnostic output from this module
# 2025-06-17 00:25:33.013845: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:183] retrieving CUDA diagnostic information for host: kdplab01
# 2025-06-17 00:25:33.013849: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:190] hostname: kdplab01
# 2025-06-17 00:25:33.013905: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:197] libcuda reported version is: 570.153.2
# 2025-06-17 00:25:33.013942: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:201] kernel reported version is: 570.153.2
# 2025-06-17 00:25:33.013947: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:291] kernel version seems to match DSO: 570.153.2
# 2025-06-17 00:25:33.014016: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:197] libcuda reported version is: 570.153.2
# 2025-06-17 00:25:33.014048: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:201] kernel reported version is: 570.153.2
# 2025-06-17 00:25:33.014052: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:291] kernel version seems to match DSO: 570.153.2
# 2025-06-17 00:25:33.017576: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2025-06-17 00:25:33.017575: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2025-06-17 00:25:33.017625: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:167] env: CUDA_VISIBLE_DEVICES=""
# 2025-06-17 00:25:33.017625: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:167] env: CUDA_VISIBLE_DEVICES=""
# 2025-06-17 00:25:33.017639: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:170] CUDA_VISIBLE_DEVICES is set to an empty string - this hides all GPUs from CUDA
# 2025-06-17 00:25:33.017639: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:170] CUDA_VISIBLE_DEVICES is set to an empty string - this hides all GPUs from CUDA
# 2025-06-17 00:25:33.017651: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:178] verbose logging is disabled. Rerun with verbose logging (usually --v=1 or --vmodule=cuda_diagnostics=1) to get more diagnostic output from this module
# 2025-06-17 00:25:33.017651: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:178] verbose logging is disabled. Rerun with verbose logging (usually --v=1 or --vmodule=cuda_diagnostics=1) to get more diagnostic output from this module
# 2025-06-17 00:25:33.017659: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:183] retrieving CUDA diagnostic information for host: kdplab01
# 2025-06-17 00:25:33.017659: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:183] retrieving CUDA diagnostic information for host: kdplab01
# 2025-06-17 00:25:33.017662: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:190] hostname: kdplab01
# 2025-06-17 00:25:33.017662: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:190] hostname: kdplab01
# 2025-06-17 00:25:33.018001: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:197] libcuda reported version is: 570.153.2
# 2025-06-17 00:25:33.018001: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:197] libcuda reported version is: 570.153.2
# 2025-06-17 00:25:33.018033: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:201] kernel reported version is: 570.153.2
# 2025-06-17 00:25:33.018036: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:291] kernel version seems to match DSO: 570.153.2
# 2025-06-17 00:25:33.018039: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:201] kernel reported version is: 570.153.2
# 2025-06-17 00:25:33.018042: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:291] kernel version seems to match DSO: 570.153.2
# 2025-06-17 00:25:33.027762: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2025-06-17 00:25:33.027818: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:167] env: CUDA_VISIBLE_DEVICES=""
# 2025-06-17 00:25:33.027830: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:170] CUDA_VISIBLE_DEVICES is set to an empty string - this hides all GPUs from CUDA
# 2025-06-17 00:25:33.027839: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:178] verbose logging is disabled. Rerun with verbose logging (usually --v=1 or --vmodule=cuda_diagnostics=1) to get more diagnostic output from this module
# 2025-06-17 00:25:33.027846: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:183] retrieving CUDA diagnostic information for host: kdplab01
# 2025-06-17 00:25:33.027848: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:190] hostname: kdplab01
# 2025-06-17 00:25:33.028148: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:197] libcuda reported version is: 570.153.2
# 2025-06-17 00:25:33.028179: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:201] kernel reported version is: 570.153.2
# 2025-06-17 00:25:33.028182: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:291] kernel version seems to match DSO: 570.153.2
# 2025-06-17 00:25:33.219965: I tensorflow/core/kernels/data/tf_record_dataset_op.cc:381] TFRecordDataset `buffer_size` is unspecified, default to 262144
# 2025-06-17 00:25:33.220527: I tensorflow/core/kernels/data/tf_record_dataset_op.cc:381] TFRecordDataset `buffer_size` is unspecified, default to 262144
# 2025-06-17 00:25:33.244555: I tensorflow/core/kernels/data/tf_record_dataset_op.cc:381] TFRecordDataset `buffer_size` is unspecified, default to 262144
# 2025-06-17 00:25:33.245102: I tensorflow/core/kernels/data/tf_record_dataset_op.cc:381] TFRecordDataset `buffer_size` is unspecified, default to 262144
# 2025-06-17 00:25:33.248255: I tensorflow/core/kernels/data/tf_record_dataset_op.cc:381] TFRecordDataset `buffer_size` is unspecified, default to 262144
# 2025-06-17 00:25:33.248591: I tensorflow/core/kernels/data/tf_record_dataset_op.cc:381] TFRecordDataset `buffer_size` is unspecified, default to 262144
# 2025-06-17 00:25:33.251382: I tensorflow/core/kernels/data/tf_record_dataset_op.cc:381] TFRecordDataset `buffer_size` is unspecified, default to 262144
# 2025-06-17 00:25:33.251383: I tensorflow/core/kernels/data/tf_record_dataset_op.cc:381] TFRecordDataset `buffer_size` is unspecified, default to 262144
# 2025-06-17 00:25:33.256839: I tensorflow/core/kernels/data/tf_record_dataset_op.cc:381] TFRecordDataset `buffer_size` is unspecified, default to 262144
# 2025-06-17 00:25:33.257320: I tensorflow/core/kernels/data/tf_record_dataset_op.cc:381] TFRecordDataset `buffer_size` is unspecified, default to 262144
# Completed 'cosine_restarts'
# Completed 'const_1e-2'
# Completed 'piecewise'
# Completed 'exp_decay'
# Completed 'poly_decay'
# Completed 'reduce_plateau'
# Completed 'const_1e-4'
# Completed 'const_1e-3'
# Completed 'cosine_decay'
# Completed 'inv_time_decay'

# %%
import sys
import os
from concurrent.futures import ProcessPoolExecutor, as_completed
from pathlib import Path
import matplotlib.pyplot as plt

# 1) Update this path to where OptimizedDataGenerator4.py resides
sys.path.append('.')  # directory containing OptimizedDataGenerator4.py
os.environ['CUDA_VISIBLE_DEVICES'] = ''  # Force CPU-only

import OptimizedDataGenerator4 as ODG
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# ─── Model definition ─────────────────────────────────────────────────────────
def CreateXYProfileModel():
    x = tf.keras.Input((21,1), name="x_profile")
    y = tf.keras.Input((13,1), name="y_profile")
    xf = tf.keras.layers.Flatten()(x)
    yf = tf.keras.layers.Flatten()(y)
    c  = tf.keras.layers.Concatenate()([xf, yf])
    h1 = tf.keras.layers.Dense(64, activation="relu")(c)
    h2 = tf.keras.layers.Dense(16, activation="relu")(h1)
    out= tf.keras.layers.Dense(1, activation="sigmoid")(h2)
    return tf.keras.Model([x, y], out)

# ─── Data generators factory (no quantization) ───────────────────────────────
base_dir       = BASE_DIR
train_dir      = TRAIN_DIR
validation_dir = VALIDATION_DIR

def make_gens():
    train_gen = ODG.OptimizedDataGenerator(
        load_records=True,
        tf_records_dir=str(TRAIN_DIR),
        x_feature_description=["x_profile", "y_profile"]
    )
    val_gen = ODG.OptimizedDataGenerator(
        load_records=True,
        tf_records_dir=str(VALIDATION_DIR),
        x_feature_description=["x_profile", "y_profile"]
    )
    return train_gen, val_gen

# ─── Learning-rate-per-epoch tracker ─────────────────────────────────────────
class LrTracker(tf.keras.callbacks.Callback):
    def __init__(self, steps_per_epoch):
        super().__init__()
        self.steps = steps_per_epoch
        self.lrs = []
    def on_epoch_end(self, epoch, logs=None):
        opt = self.model.optimizer
        lr_schedule = opt.learning_rate
        if isinstance(lr_schedule, tf.keras.optimizers.schedules.LearningRateSchedule):
            global_step = (epoch + 1) * self.steps
            lr_value = lr_schedule(global_step).numpy()
        else:
            lr_value = float(lr_schedule)
        self.lrs.append(lr_value)

# ─── Single-run trainer returns history + lrs ─────────────────────────────────
def train_and_evaluate(config):
    train_gen, val_gen = make_gens()
    steps, epochs = len(train_gen), 120

    model = CreateXYProfileModel()
    lr_tracker = LrTracker(steps)
    callbacks = [
        EarlyStopping(monitor="val_loss", patience=20, restore_best_weights=True),
        lr_tracker
    ]

    kind = config["type"]
    if kind == "constant":
        optimizer = tf.keras.optimizers.Adam(learning_rate=config["lr"])
    elif kind == "cosine_decay":
        sched = tf.keras.optimizers.schedules.CosineDecay(
            initial_learning_rate=config["initial_lr"],
            decay_steps=steps * epochs,
            alpha=config.get("alpha", 0.0)
        )
        optimizer = tf.keras.optimizers.Adam(learning_rate=sched)
    elif kind == "cosine_restarts":
        sched = tf.keras.optimizers.schedules.CosineDecayRestarts(
            initial_learning_rate=config["initial_lr"],
            first_decay_steps=(steps * epochs) // config.get("restarts_divisor", 3),
            alpha=config.get("alpha", 0.0)
        )
        optimizer = tf.keras.optimizers.Adam(learning_rate=sched)
    elif kind == "exponential_decay":
        sched = tf.keras.optimizers.schedules.ExponentialDecay(
            initial_learning_rate=config["initial_lr"],
            decay_steps=(steps * epochs) // config.get("decay_divisor", 10),
            decay_rate=config.get("decay_rate", 0.96),
            staircase=config.get("staircase", True)
        )
        optimizer = tf.keras.optimizers.Adam(learning_rate=sched)
    elif kind == "polynomial_decay":
        sched = tf.keras.optimizers.schedules.PolynomialDecay(
            initial_learning_rate=config["initial_lr"],
            decay_steps=steps * epochs,
            end_learning_rate=config.get("end_lr", 1e-5),
            power=config.get("power", 1.0)
        )
        optimizer = tf.keras.optimizers.Adam(learning_rate=sched)
    elif kind == "inverse_time_decay":
        sched = tf.keras.optimizers.schedules.InverseTimeDecay(
            initial_learning_rate=config["initial_lr"],
            decay_steps=(steps * epochs) // config.get("decay_divisor", 10),
            decay_rate=config.get("decay_rate", 1.0),
            staircase=config.get("staircase", True)
        )
        optimizer = tf.keras.optimizers.Adam(learning_rate=sched)
    elif kind == "piecewise":
        sched = tf.keras.optimizers.schedules.PiecewiseConstantDecay(
            boundaries=config["boundaries"],
            values=config["values"]
        )
        optimizer = tf.keras.optimizers.Adam(learning_rate=sched)
    elif kind == "reduce_on_plateau":
        optimizer = tf.keras.optimizers.Adam(learning_rate=config["lr"])
        callbacks.append(ReduceLROnPlateau(
            monitor="val_loss",
            factor=config.get("factor", 0.5),
            patience=config.get("patience", 10),
            verbose=1
        ))
    else:
        raise ValueError(f"Unknown scheduler type {kind!r}")

    model.compile(optimizer=optimizer, loss="binary_crossentropy", metrics=["accuracy"])
    print(f"Starting '{config['name']}' (verbose=1)")
    history = model.fit(
        train_gen,
        validation_data=val_gen,
        epochs=epochs,
        steps_per_epoch=steps,
        callbacks=callbacks,
        shuffle=False,
        verbose=1
    )
    print(f"Completed '{config['name']}'\n")
    return config["name"], history.history, lr_tracker.lrs

# ─── All scheduler configurations ─────────────────────────────────────────────
configs = [
    {"name":"const_1e-3",     "type":"constant",          "lr":1e-3},
    {"name":"const_1e-4",     "type":"constant",          "lr":1e-4},
    {"name":"const_1e-2",     "type":"constant",          "lr":1e-2},
    {"name":"cosine_decay",   "type":"cosine_decay",      "initial_lr":1e-3, "alpha":0.0},
    {"name":"cosine_restarts","type":"cosine_restarts",   "initial_lr":1e-3, "restarts_divisor":3, "alpha":0.0},
    {"name":"exp_decay",      "type":"exponential_decay", "initial_lr":1e-3, "decay_rate":0.96, "decay_divisor":10, "staircase":True},
    {"name":"poly_decay",     "type":"polynomial_decay",  "initial_lr":1e-3, "end_lr":1e-5, "power":2.0},
    {"name":"inv_time_decay", "type":"inverse_time_decay","initial_lr":1e-3, "decay_rate":1.0, "decay_divisor":10, "staircase":True},
    {"name":"piecewise",      "type":"piecewise",         "boundaries":[3000,6000], "values":[1e-3,1e-4,1e-5]},
    {"name":"reduce_plateau", "type":"reduce_on_plateau", "lr":1e-3, "factor":0.5, "patience":10},
]

# ─── Run all in parallel on CPU ────────────────────────────────────────────────
histories = {}
with ProcessPoolExecutor(max_workers=len(configs)) as executor:
    futures = {executor.submit(train_and_evaluate, cfg): cfg["name"] for cfg in configs}
    for fut in as_completed(futures):
        name, hist, lrs = fut.result()
        histories[name] = (hist, lrs)

# ─── Plot separate graphs ──────────────────────────────────────────────────────
for name, (h, lrs) in histories.items():
    epochs = len(h['accuracy'])
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
    # Accuracy curve
    ax1.plot(range(1, epochs+1), h['accuracy'], label='Train')
    ax1.plot(range(1, epochs+1), h['val_accuracy'], '--', label='Val')
    ax1.set_title(f"{name} Accuracy\nFinal Train={h['accuracy'][-1]:.4f}, Val={h['val_accuracy'][-1]:.4f}")
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Accuracy')
    ax1.legend()
    ax1.grid(True)
    # Learning rate curve
    ax2.plot(range(1, epochs+1), lrs, label='LR')
    ax2.set_title(f"{name} Learning Rate")
    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('Learning Rate')
    ax2.grid(True)
    plt.tight_layout()
    plt.show()
# Out:
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# Starting 'const_1e-3' (verbose=1)
# Starting 'inv_time_decay' (verbose=1)Starting 'exp_decay' (verbose=1)
#
# Starting 'cosine_restarts' (verbose=1)
# Starting 'reduce_plateau' (verbose=1)Starting 'const_1e-2' (verbose=1)
#
# Starting 'const_1e-4' (verbose=1)
# Starting 'piecewise' (verbose=1)
# Starting 'poly_decay' (verbose=1)Starting 'cosine_decay' (verbose=1)
# 2025-06-17 00:42:38.757550: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2025-06-17 00:42:38.757583: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:167] env: CUDA_VISIBLE_DEVICES=""
# 2025-06-17 00:42:38.757592: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:170] CUDA_VISIBLE_DEVICES is set to an empty string - this hides all GPUs from CUDA
# 2025-06-17 00:42:38.757599: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:178] verbose logging is disabled. Rerun with verbose logging (usually --v=1 or --vmodule=cuda_diagnostics=1) to get more diagnostic output from this module
# 2025-06-17 00:42:38.757604: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:183] retrieving CUDA diagnostic information for host: kdplab01
# 2025-06-17 00:42:38.757606: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:190] hostname: kdplab01
# 2025-06-17 00:42:38.757780: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:197] libcuda reported version is: 570.153.2
# 2025-06-17 00:42:38.757800: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:201] kernel reported version is: 570.153.2
# 2025-06-17 00:42:38.757802: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:291] kernel version seems to match DSO: 570.153.2
# 2025-06-17 00:42:38.764799: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2025-06-17 00:42:38.764837: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:167] env: CUDA_VISIBLE_DEVICES=""
# 2025-06-17 00:42:38.764847: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:170] CUDA_VISIBLE_DEVICES is set to an empty string - this hides all GPUs from CUDA
# 2025-06-17 00:42:38.764855: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:178] verbose logging is disabled. Rerun with verbose logging (usually --v=1 or --vmodule=cuda_diagnostics=1) to get more diagnostic output from this module
# 2025-06-17 00:42:38.764862: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:183] retrieving CUDA diagnostic information for host: kdplab01
# 2025-06-17 00:42:38.764866: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:190] hostname: kdplab01
# 2025-06-17 00:42:38.765044: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:197] libcuda reported version is: 570.153.2
# 2025-06-17 00:42:38.765068: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:201] kernel reported version is: 570.153.2
# 2025-06-17 00:42:38.765072: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:291] kernel version seems to match DSO: 570.153.2
# 2025-06-17 00:42:38.769069: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2025-06-17 00:42:38.769110: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:167] env: CUDA_VISIBLE_DEVICES=""
# 2025-06-17 00:42:38.769122: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:170] CUDA_VISIBLE_DEVICES is set to an empty string - this hides all GPUs from CUDA
# 2025-06-17 00:42:38.769131: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:178] verbose logging is disabled. Rerun with verbose logging (usually --v=1 or --vmodule=cuda_diagnostics=1) to get more diagnostic output from this module
# 2025-06-17 00:42:38.769135: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:183] retrieving CUDA diagnostic information for host: kdplab01
# 2025-06-17 00:42:38.769138: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:190] hostname: kdplab01
# 2025-06-17 00:42:38.769310: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:197] libcuda reported version is: 570.153.2
# 2025-06-17 00:42:38.769338: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:201] kernel reported version is: 570.153.2
# 2025-06-17 00:42:38.769341: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:291] kernel version seems to match DSO: 570.153.2
# 2025-06-17 00:42:38.769910: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2025-06-17 00:42:38.769945: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:167] env: CUDA_VISIBLE_DEVICES=""
# 2025-06-17 00:42:38.769954: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:170] CUDA_VISIBLE_DEVICES is set to an empty string - this hides all GPUs from CUDA
# 2025-06-17 00:42:38.769964: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:178] verbose logging is disabled. Rerun with verbose logging (usually --v=1 or --vmodule=cuda_diagnostics=1) to get more diagnostic output from this module
# 2025-06-17 00:42:38.769969: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:183] retrieving CUDA diagnostic information for host: kdplab01
# 2025-06-17 00:42:38.769971: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:190] hostname: kdplab01
# 2025-06-17 00:42:38.770137: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:197] libcuda reported version is: 570.153.2
# 2025-06-17 00:42:38.770164: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:201] kernel reported version is: 570.153.2
# 2025-06-17 00:42:38.770167: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:291] kernel version seems to match DSO: 570.153.2
# 2025-06-17 00:42:38.770541: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2025-06-17 00:42:38.770575: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:167] env: CUDA_VISIBLE_DEVICES=""
# 2025-06-17 00:42:38.770583: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:170] CUDA_VISIBLE_DEVICES is set to an empty string - this hides all GPUs from CUDA
# 2025-06-17 00:42:38.770593: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:178] verbose logging is disabled. Rerun with verbose logging (usually --v=1 or --vmodule=cuda_diagnostics=1) to get more diagnostic output from this module
# 2025-06-17 00:42:38.770598: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:183] retrieving CUDA diagnostic information for host: kdplab01
# 2025-06-17 00:42:38.770600: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:190] hostname: kdplab01
# 2025-06-17 00:42:38.770598: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2025-06-17 00:42:38.770632: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:167] env: CUDA_VISIBLE_DEVICES=""
# 2025-06-17 00:42:38.770640: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:170] CUDA_VISIBLE_DEVICES is set to an empty string - this hides all GPUs from CUDA
# 2025-06-17 00:42:38.770649: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:178] verbose logging is disabled. Rerun with verbose logging (usually --v=1 or --vmodule=cuda_diagnostics=1) to get more diagnostic output from this module
# 2025-06-17 00:42:38.770654: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:183] retrieving CUDA diagnostic information for host: kdplab01
# 2025-06-17 00:42:38.770657: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:190] hostname: kdplab01
# 2025-06-17 00:42:38.770806: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:197] libcuda reported version is: 570.153.2
# 2025-06-17 00:42:38.770840: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:201] kernel reported version is: 570.153.2
# 2025-06-17 00:42:38.770843: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:291] kernel version seems to match DSO: 570.153.2
# 2025-06-17 00:42:38.770856: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:197] libcuda reported version is: 570.153.2
# 2025-06-17 00:42:38.770887: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:201] kernel reported version is: 570.153.2
# 2025-06-17 00:42:38.770891: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:291] kernel version seems to match DSO: 570.153.2
# 2025-06-17 00:42:38.774305: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2025-06-17 00:42:38.774332: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2025-06-17 00:42:38.774349: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:167] env: CUDA_VISIBLE_DEVICES=""
# 2025-06-17 00:42:38.774360: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:170] CUDA_VISIBLE_DEVICES is set to an empty string - this hides all GPUs from CUDA
# 2025-06-17 00:42:38.774367: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:178] verbose logging is disabled. Rerun with verbose logging (usually --v=1 or --vmodule=cuda_diagnostics=1) to get more diagnostic output from this module
# 2025-06-17 00:42:38.774369: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:167] env: CUDA_VISIBLE_DEVICES=""
# 2025-06-17 00:42:38.774371: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:183] retrieving CUDA diagnostic information for host: kdplab01
# 2025-06-17 00:42:38.774374: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:190] hostname: kdplab01
# 2025-06-17 00:42:38.774376: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:170] CUDA_VISIBLE_DEVICES is set to an empty string - this hides all GPUs from CUDA
# 2025-06-17 00:42:38.774385: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:178] verbose logging is disabled. Rerun with verbose logging (usually --v=1 or --vmodule=cuda_diagnostics=1) to get more diagnostic output from this module
# 2025-06-17 00:42:38.774389: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:183] retrieving CUDA diagnostic information for host: kdplab01
# 2025-06-17 00:42:38.774391: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:190] hostname: kdplab01
# 2025-06-17 00:42:38.774545: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:197] libcuda reported version is: 570.153.2
# 2025-06-17 00:42:38.774559: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:197] libcuda reported version is: 570.153.2
# 2025-06-17 00:42:38.774586: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:201] kernel reported version is: 570.153.2
# 2025-06-17 00:42:38.774589: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:201] kernel reported version is: 570.153.2
# 2025-06-17 00:42:38.774590: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:291] kernel version seems to match DSO: 570.153.2
# 2025-06-17 00:42:38.774591: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:291] kernel version seems to match DSO: 570.153.2
# 2025-06-17 00:42:38.784135: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2025-06-17 00:42:38.784195: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:167] env: CUDA_VISIBLE_DEVICES=""
# 2025-06-17 00:42:38.784211: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:170] CUDA_VISIBLE_DEVICES is set to an empty string - this hides all GPUs from CUDA
# 2025-06-17 00:42:38.784226: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:178] verbose logging is disabled. Rerun with verbose logging (usually --v=1 or --vmodule=cuda_diagnostics=1) to get more diagnostic output from this module
# 2025-06-17 00:42:38.784232: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:183] retrieving CUDA diagnostic information for host: kdplab01
# 2025-06-17 00:42:38.784236: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:190] hostname: kdplab01
# 2025-06-17 00:42:38.784509: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:197] libcuda reported version is: 570.153.2
# 2025-06-17 00:42:38.784571: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:201] kernel reported version is: 570.153.2
# 2025-06-17 00:42:38.784576: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:291] kernel version seems to match DSO: 570.153.2
# 2025-06-17 00:42:38.790343: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2025-06-17 00:42:38.790400: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:167] env: CUDA_VISIBLE_DEVICES=""
# 2025-06-17 00:42:38.790414: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:170] CUDA_VISIBLE_DEVICES is set to an empty string - this hides all GPUs from CUDA
# 2025-06-17 00:42:38.790427: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:178] verbose logging is disabled. Rerun with verbose logging (usually --v=1 or --vmodule=cuda_diagnostics=1) to get more diagnostic output from this module
# 2025-06-17 00:42:38.790432: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:183] retrieving CUDA diagnostic information for host: kdplab01
# 2025-06-17 00:42:38.790434: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:190] hostname: kdplab01
# 2025-06-17 00:42:38.790686: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:197] libcuda reported version is: 570.153.2
# 2025-06-17 00:42:38.790750: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:201] kernel reported version is: 570.153.2
# 2025-06-17 00:42:38.790754: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:291] kernel version seems to match DSO: 570.153.2
# 2025-06-17 00:42:39.023698: I tensorflow/core/kernels/data/tf_record_dataset_op.cc:381] TFRecordDataset `buffer_size` is unspecified, default to 262144
# 2025-06-17 00:42:39.025362: I tensorflow/core/kernels/data/tf_record_dataset_op.cc:381] TFRecordDataset `buffer_size` is unspecified, default to 262144
# 2025-06-17 00:42:39.025462: I tensorflow/core/kernels/data/tf_record_dataset_op.cc:381] TFRecordDataset `buffer_size` is unspecified, default to 262144
# 2025-06-17 00:42:39.025538: I tensorflow/core/kernels/data/tf_record_dataset_op.cc:381] TFRecordDataset `buffer_size` is unspecified, default to 262144
# 2025-06-17 00:42:39.025545: I tensorflow/core/kernels/data/tf_record_dataset_op.cc:381] TFRecordDataset `buffer_size` is unspecified, default to 262144
# 2025-06-17 00:42:39.028691: I tensorflow/core/kernels/data/tf_record_dataset_op.cc:381] TFRecordDataset `buffer_size` is unspecified, default to 262144
# 2025-06-17 00:42:39.029595: I tensorflow/core/kernels/data/tf_record_dataset_op.cc:381] TFRecordDataset `buffer_size` is unspecified, default to 262144
# 2025-06-17 00:42:39.037046: I tensorflow/core/kernels/data/tf_record_dataset_op.cc:381] TFRecordDataset `buffer_size` is unspecified, default to 262144
# 2025-06-17 00:42:39.051115: I tensorflow/core/kernels/data/tf_record_dataset_op.cc:381] TFRecordDataset `buffer_size` is unspecified, default to 262144
# 2025-06-17 00:42:39.051352: I tensorflow/core/kernels/data/tf_record_dataset_op.cc:381] TFRecordDataset `buffer_size` is unspecified, default to 262144
# Epoch 1/120
# Epoch 1/120
# Epoch 1/120
# Epoch 1/120
# Epoch 1/120
# Epoch 1/120
# Epoch 1/120
# Epoch 1/120
# Epoch 1/120
# Epoch 1/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 121ms/step - accuracy: 0.2895 - loss: 1.1177 - val_accuracy: 0.6073 - val_loss: 0.7259
# Epoch 2/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 135ms/step - accuracy: 0.5614 - loss: 1.5455 - val_accuracy: 0.5909 - val_loss: 0.9339
# Epoch 2/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 137ms/step - accuracy: 0.6218 - loss: 1.7426 - val_accuracy: 0.6015 - val_loss: 1.1650 - learning_rate: 0.0010
# Epoch 2/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 137ms/step - accuracy: 0.4981 - loss: 1.0765 - val_accuracy: 0.6291 - val_loss: 0.8471
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 138ms/step - accuracy: 0.4976 - loss: 2.2276 - val_accuracy: 0.5839 - val_loss: 1.3217
# Epoch 2/120
# Epoch 2/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 137ms/step - accuracy: 0.4670 - loss: 1.1723 - val_accuracy: 0.6043 - val_loss: 0.8066
# Epoch 2/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 139ms/step - accuracy: 0.4047 - loss: 1.5832 - val_accuracy: 0.4315 - val_loss: 1.3206
#  1/30 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - accuracy: 0.1560 - loss: 1.6387Epoch 2/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 140ms/step - accuracy: 0.7101 - loss: 4.5598 - val_accuracy: 0.6049 - val_loss: 0.6731
# Epoch 2/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 141ms/step - accuracy: 0.2893 - loss: 2.3093 - val_accuracy: 0.6129 - val_loss: 0.7514
# Epoch 2/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 140ms/step - accuracy: 0.4693 - loss: 0.9174 - val_accuracy: 0.6170 - val_loss: 0.6563
#  1/30 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - accuracy: 0.1915 - loss: 2.1631Epoch 2/120
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 119ms/step - accuracy: 0
# %%
import os
import re
import glob
import sys
from concurrent.futures import ProcessPoolExecutor, as_completed

# ─── 0) Ensure we can import ODG and force CPU-only ──────────────────────────
parentdir = os.path.dirname(os.getcwd())
sys.path.insert(0, parentdir)
os.environ['CUDA_VISIBLE_DEVICES'] = ''

import OptimizedDataGenerator4 as ODG
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
# Out:
# 2025-06-29 22:06:03.837706: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-06-29 22:06:03.839042: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-06-29 22:06:03.842332: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-06-29 22:06:03.851288: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %%
# ─── 1) Model factory ─────────────────────────────────────────────────────────
def CreatePairedProfileModel():
    # Inputs
    x_profile = tf.keras.Input(shape=(21, 1), name="x_profile")
    y_profile = tf.keras.Input(shape=(13, 1), name="y_profile")
    y_local   = tf.keras.Input(shape=(1,),   name="y_local")
    z_global  = tf.keras.Input(shape=(1,),   name="z_global")

    # Flatten the profiles
    x_flat = tf.keras.layers.Flatten(name="flatten_x")(x_profile)
    y_flat = tf.keras.layers.Flatten(name="flatten_y")(y_profile)

    # Pair 1: x_flat + z_global
    xz = tf.keras.layers.Concatenate(name="concat_x_z")([x_flat, z_global])
    xz_hidden = tf.keras.layers.Dense(64, activation="relu", name="xz_hidden")(xz)

    # Pair 2: y_flat + y_local
    yl = tf.keras.layers.Concatenate(name="concat_y_y")([y_flat, y_local])
    yl_hidden = tf.keras.layers.Dense(64, activation="relu", name="yl_hidden")(yl)

    # Merge both streams
    merged = tf.keras.layers.Concatenate(name="concat_merged")([xz_hidden, yl_hidden])
    dense_final = tf.keras.layers.Dense(32, activation="relu", name="final_hidden")(merged)
    output = tf.keras.layers.Dense(1, activation="sigmoid", name="output")(dense_final)

    return tf.keras.Model(
        inputs=[x_profile, y_profile, y_local, z_global],
        outputs=output,
        name="PairedProfileModel"
    )

# ─── 2) Worker: train & return history ────────────────────────────────────────
def train_for_batch(batch_dir, num_epochs=150, initial_lr=1e-3):
    # parse batch size
    m = re.search(r"Batch(\d+)_", os.path.basename(batch_dir))
    batch_size = int(m.group(1))

    train_dir = os.path.join(batch_dir, "tfrecords_train")
    val_dir   = os.path.join(batch_dir, "tfrecords_validation")

    # data generators
    train_gen = ODG.OptimizedDataGenerator(
        load_records=True,
        tf_records_dir=str(train_dir),
        x_feature_description=["x_profile", "y_profile", 'y_local', 'z_global'],
        batch_size=batch_size
    )
    val_gen = ODG.OptimizedDataGenerator(
        load_records=True,
        tf_records_dir=str(val_dir),
        x_feature_description=["x_profile", "y_profile",'y_local', 'z_global'],
        batch_size=batch_size
    )

    steps_per_epoch = len(train_gen)
    total_steps     = steps_per_epoch * num_epochs

    # fresh model/context
    tf.keras.backend.clear_session()
    model = CreatePairedProfileModel()

    # cosine decay schedule
    lr_schedule = tf.keras.optimizers.schedules.CosineDecay(
        initial_learning_rate=initial_lr,
        decay_steps=total_steps,
        alpha=0.0
    )
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule)

    model.compile(
        optimizer=optimizer,
        loss="binary_crossentropy",
        metrics=["accuracy"]
    )
    es = EarlyStopping(monitor="val_loss", patience=60, restore_best_weights=True)

    print(f"[PID {os.getpid()}] Training batch size = {batch_size}")
    history = model.fit(
        train_gen,
        validation_data=val_gen,
        epochs=num_epochs,
        steps_per_epoch=steps_per_epoch,
        callbacks=[es],
        shuffle=False,
        verbose=1
    )
    return batch_size, history.history

# ─── 3) Main: discover folders, parallelize, collect, then plot ─────────────
if __name__ == "__main__":
    base_dir = "/local/d1/smartpixML/filtering_models/Time19"
    batch_dirs = sorted(
        glob.glob(os.path.join(base_dir, "Batch*_Time19")),
        key=lambda p: int(re.search(r"Batch(\d+)_", os.path.basename(p)).group(1))
    )

    results = {}
    with ProcessPoolExecutor(max_workers=len(batch_dirs)) as executor:
        futures = {executor.submit(train_for_batch, bd): bd for bd in batch_dirs}
        for fut in as_completed(futures):
            bs, hist = fut.result()
            results[bs] = hist

    # plot one accuracy curve per batch size
    for bs in sorted(results):
        h = results[bs]
        plt.figure(figsize=(6,4))
        plt.plot(h["accuracy"],     label="train_acc")
        plt.plot(h["val_accuracy"], label="val_acc")
        plt.title(f"Accuracy Curves — Batch Size {bs}")
        plt.xlabel("Epoch")
        plt.ylabel("Accuracy")
        plt.legend()
        plt.tight_layout()
        plt.show()
# Out:
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# ...

# %%
# ─── Plot Best Validation Accuracy vs. Batch Size (equal spacing) ───────────
import matplotlib.pyplot as plt

batch_sizes = sorted(results.keys())
best_val_acc = [max(results[bs]['val_accuracy']) for bs in batch_sizes]

# positions 0,1,2,… rather than actual batch_size values
x = list(range(len(batch_sizes)))

plt.figure(figsize=(8,5))
plt.bar(x, best_val_acc, edgecolor='k')
plt.xticks(x, batch_sizes, rotation=45)       # label bars by batch size
plt.xlabel('Batch Size', fontsize=12)
plt.ylabel('Best Validation Accuracy', fontsize=12)
plt.title('Best Validation Accuracy vs. Batch Size', fontsize=14)
plt.tight_layout()
plt.show()

# %%
import pandas as pd

# assume `results` is already defined
batch_sizes = sorted(results.keys())
best_val_acc = [max(results[bs]['val_accuracy']) for bs in batch_sizes]

# build a DataFrame and print it
df = pd.DataFrame({
    'Batch Size': batch_sizes,
    'Best Val Accuracy': best_val_acc
})
print(df.to_string(index=False, float_format='%.4f'))
# Out:
#  Batch Size  Best Val Accuracy
#          64             0.9006
#         128             0.9018
#         256             0.9040
#         512             0.9037
#        1024             0.9025
#        2048             0.8859
#        4096             0.8568
#        8192             0.8290
